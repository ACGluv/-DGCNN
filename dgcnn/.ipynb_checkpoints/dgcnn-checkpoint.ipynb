# %%
'''from keras import backend as K
# set GPU memory 
if('tensorflow' == K.backend()):
    import tensorflow as tf
    from keras.backend.tensorflow_backend import set_session

    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    sess = tf.Session(config=config)'''

# %%
'''import tensorflow as tf
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.3)
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))'''

# %%
'''import tensorflow as tf
from keras.backend.tensorflow_backend import set_session
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.3
set_session(tf.Session(config=config))'''

# %%
#! -*- coding:utf-8 -*-

import codecs
import json
import os
#os.environ['TF2_BEHAVIOR'] = '1'
import re
import warnings
import sys
sys.path.append("../evaluate_tool")
import evaluate

# 快速分词器
import jieba_fast as jieba
# 向量操作框架
import numpy as np
# 词向量读取
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
# 进度条
from tqdm import tqdm
from evaluate import load_qid_answer_expand, is_exact_match_answer, cacu_character_level_f

warnings.filterwarnings("ignore")  # 忽略keras带来的满屏警告

# %%
mode = 0
char_size = 128
max_len = 256
min_count = 16
batch_size = 128

# train_page_size = 3096

# %%
#word2vec = KeyedVectors.load_word2vec_format('../word2vec_baike/sgns.weibo.bigram')
word2vec = Word2Vec.load('../word2vec_baike/word2vec_baike')
id2word = {i + 1: j for i, j in enumerate(word2vec.wv.index2word)}
word2id = {j: i for i, j in id2word.items()}
word2vec = word2vec.wv.syn0
word_size = word2vec.shape[1]
word2vec = np.concatenate([np.zeros((1, word_size)), word2vec])

# %%
for w in word2id:
    if w not in jieba.dt.FREQ:
        jieba.add_word(w)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\Ma\AppData\Local\Temp\jieba.cache
# Loading model cost 0.811 seconds.
# Prefix dict has been built succesfully.

# %%
def tokenize(s):
    return jieba.lcut(s, HMM=False)

# %%
def sent2vec(S):
    """S格式：[[w1, w2]]
    """
    V = []
    for s in S:
        V.append([])
        for w in s:
            for _ in w:
                V[-1].append(word2id.get(w, 0))
    V = seq_padding(V)
    V = word2vec[V]
    return V

# %%
webqa_data = json.load(open('../datasets/WebQA.json', encoding='utf-8'))
sogou_data = json.load(open('../datasets/SogouQA.json', encoding='utf-8'))
# if train_page_size:
#     webqa_data = webqa_data[:train_page_size]
#     sogou_data = sogou_data[:train_page_size]

# %%
if not os.path.exists('../dgcnn_config.json'):
    chars = {}
    for D in [webqa_data, sogou_data]:
        for d in tqdm(iter(D)):
            for c in d['question']:
                chars[c] = chars.get(c, 0) + 1
            for p in d['passages']:
                for c in p['passage']:
                    chars[c] = chars.get(c, 0) + 1
    chars = {i: j for i, j in chars.items() if j >= min_count}
    id2char = {i + 2: j for i, j in enumerate(chars)}  # 0: mask, 1: padding
    char2id = {j: i for i, j in id2char.items()}
    json.dump([id2char, char2id], open('../dgcnn_config.json', 'w'))
else:
    id2char, char2id = json.load(open('../dgcnn_config.json'))

# %%
if not os.path.exists('../random_order.json'):
    random_order = list(range(len(sogou_data)))
    np.random.shuffle(random_order)
    json.dump(
        random_order,
        open('../random_order.json', 'w'),
        indent=4
    )
else:
    random_order = json.load(open('../random_order.json'))

# %%
train_data = [sogou_data[j] for i, j in enumerate(random_order) if i % 3 != mode]
dev_data = [sogou_data[j] for i, j in enumerate(random_order) if i % 180 == mode]
train_data.extend(train_data)
train_data.extend(webqa_data)

# %%
def seq_padding(X, padding=0):
    L = [len(x) for x in X]
    ML = max(L)
    return np.array([
        np.concatenate([x, [padding] * (ML - len(x))]) if len(x) < ML else x for x in X
    ])

# %%
class data_generator(object):
    def __init__(self, data, batch_size=batch_size):
        self.data = data
        self.batch_size = batch_size
        self.steps = len(self.data) // self.batch_size
        if len(self.data) % self.batch_size != 0:
            self.steps += 1

    def random_generate(self, s):
        l = max_len // 2 + max_len % 2
        if len(s) > l:
            p = np.random.random()
            if p > 0.5:
                i = np.random.randint(len(s) - l + 1)
                j = np.random.randint(l + i, min(len(s), i + max_len) + 1)
                return s[i: j]
            else:
                return s[: max_len]
        else:
            return s

    def __len__(self):
        return self.steps

    def __iter__(self):
        while True:
            idxs = list(range(len(self.data)))
            np.random.shuffle(idxs)
            Q1, Q2, P1, P2, A1, A2 = [], [], [], [], [], []
            for i in idxs:
                d = self.data[i]
                # 问题
                q_text = d['question']
                q_text_words = tokenize(q_text)
                q_text = ''.join(q_text_words)
                qid = [char2id.get(c, 1) for c in q_text]
                # 篇章
                pi = np.random.choice(len(d['passages']))
                p = d['passages'][pi]
                p_text = self.random_generate(p['passage'])
                p_text_words = tokenize(p_text)
                p_text = ''.join(p_text_words)
                pid = [char2id.get(c, 1) for c in p_text]
                # 答案
                a1, a2 = np.zeros(len(p_text)), np.zeros(len(p_text))
                if p['answer']:
                    for j in re.finditer(re.escape(p['answer']), p_text):
                        a1[j.start()] = 1
                        a2[j.end() - 1] = 1
                # 组合
                Q1.append(qid)
                Q2.append(q_text_words)
                P1.append(pid)
                P2.append(p_text_words)
                A1.append(a1)
                A2.append(a2)
                if len(Q1) == self.batch_size or i == idxs[-1]:
                    Q1 = seq_padding(Q1)
                    Q2 = sent2vec(Q2)
                    P1 = seq_padding(P1)
                    P2 = sent2vec(P2)
                    A1 = seq_padding(A1)
                    A2 = seq_padding(A2)
                    yield [Q1, Q2, P1, P2, A1, A2], None
                    Q1, Q2, P1, P2, A1, A2 = [], [], [], [], [], []

# %%
from keras.layers import *
from keras.models import Model
import keras.backend as K
from keras.callbacks import Callback
from keras_radam import RAdam
# Out:
# Using TensorFlow backend.

# %%
class OurLayer(Layer):
    """定义新的Layer，增加reuse方法，允许在定义Layer时调用现成的层
    """

    def reuse(self, layer, *args, **kwargs):
        if not layer.built:
            if len(args) > 0:
                inputs = args[0]
            else:
                inputs = kwargs['inputs']
            if isinstance(inputs, list):
                input_shape = [K.int_shape(x) for x in inputs]
            else:
                input_shape = K.int_shape(inputs)
            layer.build(input_shape)
        outputs = layer.call(*args, **kwargs)
        for w in layer.trainable_weights:
            if w not in self._trainable_weights:
                self._trainable_weights.append(w)
        for w in layer.non_trainable_weights:
            if w not in self._non_trainable_weights:
                self._non_trainable_weights.append(w)
        return outputs

# %%
class AttentionPooling1D(OurLayer):
    """
    通过加性Attention，将向量序列融合为一个定长向量
    """

    def __init__(self, h_dim=None, **kwargs):
        super(AttentionPooling1D, self).__init__(**kwargs)
        self.h_dim = h_dim

    def build(self, input_shape):
        super(AttentionPooling1D, self).build(input_shape)
        if self.h_dim is None:
            self.h_dim = input_shape[0][-1]
        self.k_dense = Dense(
            self.h_dim,
            use_bias=False,
            activation='tanh'
        )
        self.o_dense = Dense(1, use_bias=False)

    def call(self, inputs):
        xo, mask = inputs
        x = xo
        x = self.reuse(self.k_dense, x)
        x = self.reuse(self.o_dense, x)
        x = x - (1 - mask) * 1e12
        x = K.softmax(x, 1)
        return K.sum(x * xo, 1)

    def compute_output_shape(self, input_shape):
        return None, input_shape[0][-1]

# %%
class DilatedGatedConv1D(OurLayer):
    """
    膨胀门卷积（DGCNN）
    """

    def __init__(self,
                 o_dim=None,
                 k_size=3,
                 rate=1,
                 skip_connect=True,
                 drop_gate=None,
                 **kwargs):
        super(DilatedGatedConv1D, self).__init__(**kwargs)
        self.o_dim = o_dim
        self.k_size = k_size
        self.rate = rate
        self.skip_connect = skip_connect
        self.drop_gate = drop_gate

    def build(self, input_shape):
        super(DilatedGatedConv1D, self).build(input_shape)
        if self.o_dim is None:
            self.o_dim = input_shape[0][-1]
        self.conv1d = Conv1D(
            self.o_dim * 2,
            self.k_size,
            dilation_rate=self.rate,
            padding='same'
        )
        if self.skip_connect and self.o_dim != input_shape[0][-1]:
            self.conv1d_1x1 = Conv1D(self.o_dim, 1)

    def call(self, inputs):
        xo, mask = inputs
        x = xo * mask
        x = self.reuse(self.conv1d, x)
        x, g = x[..., :self.o_dim], x[..., self.o_dim:]
        if self.drop_gate is not None:
            g = K.in_train_phase(K.dropout(g, self.drop_gate), g)
        g = K.sigmoid(g)
        if self.skip_connect:
            if self.o_dim != K.int_shape(xo)[-1]:
                xo = self.reuse(self.conv1d_1x1, xo)
            return (xo * (1 - g) + x * g) * mask
        else:
            return x * g * mask

    def compute_output_shape(self, input_shape):
        return input_shape[0][:-1] + (self.o_dim,)

# %%
class MixEmbedding(OurLayer):
    """
    混合Embedding
    输入字id、词embedding，然后字id自动转字embedding，
    词embedding做一个dense，再加上字embedding，并且
    加上位置embedding。
    """

    def __init__(self, i_dim, o_dim, **kwargs):
        super(MixEmbedding, self).__init__(**kwargs)
        self.i_dim = i_dim
        self.o_dim = o_dim

    def build(self, input_shape):
        super(MixEmbedding, self).build(input_shape)
        self.char_embeddings = Embedding(self.i_dim, self.o_dim)
        self.word_dense = Dense(self.o_dim, use_bias=False)

    def call(self, inputs):
        x1, x2 = inputs
        x1 = self.reuse(self.char_embeddings, x1)
        x2 = self.reuse(self.word_dense, x2)
        return x1 + x2

    def compute_output_shape(self, input_shape):
        return input_shape[0] + (self.o_dim,)

# %%
def seq_and_vec(x):
    x, v = x
    v = K.expand_dims(v, 1)
    v = K.tile(v, [1, K.shape(x)[1], 1])
    return K.concatenate([x, v], 2)

# %%
q1_in = Input(shape=(None,))  # 问题字id输入
q2_in = Input(shape=(None, word_size))  # 问题词向量输入
p1_in = Input(shape=(None,))  # 篇章字id输入
p2_in = Input(shape=(None, word_size))  # 篇章词向量输入
a1_in = Input(shape=(None,))  # 答案左边界输入
a2_in = Input(shape=(None,))  # 答案右边界输入

q1, q2, p1, p2, a1, a2 = q1_in, q2_in, p1_in, p2_in, a1_in, a2_in
q_mask = Lambda(lambda x: K.cast(K.greater(K.expand_dims(x, 2), 0), 'float32'))(q1)
p_mask = Lambda(lambda x: K.cast(K.greater(K.expand_dims(x, 2), 0), 'float32'))(p1)

embeddings = MixEmbedding(len(char2id) + 2, char_size)

q = embeddings([q1, q2])
q = Dropout(0.1)(q)
p = embeddings([p1, p2])
p = Dropout(0.1)(p)

q = DilatedGatedConv1D(rate=1, drop_gate=0.1)([q, q_mask])
q = DilatedGatedConv1D(rate=2, drop_gate=0.1)([q, q_mask])
q = DilatedGatedConv1D(rate=1, drop_gate=0.1)([q, q_mask])
qv = AttentionPooling1D()([q, q_mask])

p = Lambda(seq_and_vec)([p, qv])
p = Dense(char_size, use_bias=False)(p)
p = DilatedGatedConv1D(rate=1, drop_gate=0.1)([p, p_mask])
p = DilatedGatedConv1D(rate=2, drop_gate=0.1)([p, p_mask])
p = DilatedGatedConv1D(rate=4, drop_gate=0.1)([p, p_mask])
p = DilatedGatedConv1D(rate=8, drop_gate=0.1)([p, p_mask])
p = DilatedGatedConv1D(rate=16, drop_gate=0.1)([p, p_mask])
p = DilatedGatedConv1D(rate=1, drop_gate=0.1)([p, p_mask])
p = Lambda(seq_and_vec)([p, qv])
pv = AttentionPooling1D()([p, p_mask])

pa = Dense(1, activation='sigmoid')(pv)
pa1 = Dense(1, activation='sigmoid')(p)
pa2 = Dense(1, activation='sigmoid')(p)
pa1 = Lambda(lambda x: x[0] * x[1][..., 0])([pa, pa1])
pa2 = Lambda(lambda x: x[0] * x[1][..., 0])([pa, pa2])

model = Model([q1_in, q2_in, p1_in, p2_in], [pa1, pa2])
model.summary()

train_model = Model([q1_in, q2_in, p1_in, p2_in, a1_in, a2_in], [pa1, pa2])
# Out:
# WARNING:tensorflow:From E:\Anaconda\envs\tf_gpu_cu10\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From E:\Anaconda\envs\tf_gpu_cu10\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From E:\Anaconda\envs\tf_gpu_cu10\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From E:\Anaconda\envs\tf_gpu_cu10\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From E:\Anaconda\envs\tf_gpu_cu10\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, None, 256)    0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None, 256)    0
# __________________________________________________________________________________________________
# mix_embedding_1 (MixEmbedding)  (None, None, 128)    929792      input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, None, 128)    0           mix_embedding_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, 1)      0           input_1[0][0]
# __________________________________________________________________________________________________
# dilated_gated_conv1d_1 (Dilated (None, None, 128)    98560       dropout_1[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# dilated_gated_conv1d_2 (Dilated (None, None, 128)    98560       dilated_gated_conv1d_1[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# dilated_gated_conv1d_3 (Dilated (None, None, 128)    98560       dilated_gated_conv1d_2[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, None, 128)    0           mix_embedding_1[1][0]
# __________________________________________________________________________________________________
# attention_pooling1d_1 (Attentio (None, 128)          16512       dilated_gated_conv1d_3[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, None, 256)    0           dropout_2[0][0]
#                                                                  attention_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, None, 128)    32768       lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, None, 1)      0           input_3[0][0]
# __________________________________________________________________________________________________
# dilated_gated_conv1d_4 (Dilated (None, None, 128)    98560       dense_4[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dilated_gated_conv1d_5 (Dilated (None, None, 128)    98560       dilated_gated_conv1d_4[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dilated_gated_conv1d_6 (Dilated (None, None, 128)    98560       dilated_gated_conv1d_5[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dilated_gated_conv1d_7 (Dilated (None, None, 128)    98560       dilated_gated_conv1d_6[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dilated_gated_conv1d_8 (Dilated (None, None, 128)    98560       dilated_gated_conv1d_7[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dilated_gated_conv1d_9 (Dilated (None, None, 128)    98560       dilated_gated_conv1d_8[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, None, 256)    0           dilated_gated_conv1d_9[0][0]
#                                                                  attention_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# attention_pooling1d_2 (Attentio (None, 256)          65792       lambda_4[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            257         attention_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, None, 1)      257         lambda_4[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, None, 1)      257         lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, None)         0           dense_7[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, None)         0           dense_7[0][0]
#                                                                  dense_9[0][0]
# ==================================================================================================
# Total params: 1,932,675
# Trainable params: 1,932,675
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
def focal_loss(y_true, y_pred):
    alpha, gamma = 0.25, 2
    y_pred = K.clip(y_pred, 1e-8, 1 - 1e-8)
    return - alpha * y_true * K.log(y_pred) * (1 - y_pred) ** gamma \
           - (1 - alpha) * (1 - y_true) * K.log(1 - y_pred) * y_pred ** gamma

# %%
loss1 = focal_loss(a1_in, pa1)
loss1 = K.sum(loss1 * p_mask[..., 0]) / K.sum(p_mask)
loss2 = focal_loss(a2_in, pa2)
loss2 = K.sum(loss2 * p_mask[..., 0]) / K.sum(p_mask)
loss = (loss1 + loss2) * 100  # 放大100倍，可读性好些，不影响Adam的优化

train_model.add_loss(loss)
train_model.compile(optimizer=RAdam(1e-3))
# Out:
# WARNING:tensorflow:From E:\Anaconda\envs\tf_gpu_cu10\lib\site-packages\keras\backend\tensorflow_backend.py:1521: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From E:\Anaconda\envs\tf_gpu_cu10\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
class ExponentialMovingAverage:
    """对模型权重进行指数滑动平均。
    用法：在model.compile之后、第一次训练之前使用；
    先初始化对象，然后执行inject方法。
    """

    def __init__(self, model, momentum=0.9999):
        self.momentum = momentum
        self.model = model
        self.ema_weights = [K.zeros(K.shape(w)) for w in model.weights]
        self.model.metrics_updates = []

    def inject(self):
        """添加更新算子到model.metrics_updates。
        """
        self.initialize()
        for w1, w2 in zip(self.ema_weights, self.model.weights):
            op = K.moving_average_update(w1, w2, self.momentum)
            self.model.metrics_updates.append(op)

    def initialize(self):
        """ema_weights初始化跟原模型初始化一致。
        """
        self.old_weights = K.batch_get_value(self.model.weights)
        K.batch_set_value(zip(self.ema_weights, self.old_weights))

    def apply_ema_weights(self):
        """备份原模型权重，然后将平均权重应用到模型上去。
        """
        self.old_weights = K.batch_get_value(self.model.weights)
        ema_weights = K.batch_get_value(self.ema_weights)
        K.batch_set_value(zip(self.model.weights, ema_weights))
        
    def me_apply_ema_weights(self):
        """将平均权重应用到模型上去。
        """
        K.batch_set_value(zip(self.model.weights, ema_weights))

    def reset_old_weights(self):
        """恢复模型到旧权重。
        """
        K.batch_set_value(zip(self.model.weights, self.old_weights))

# %%
EMAer = ExponentialMovingAverage(train_model)
EMAer.inject()

# %%
def extract_answer(q_text, p_texts, maxlen=12, threshold=0.1):
    """
    q_text为问题，p_texts为篇章集合（list）
    最终输出一个dict，dict的key为候选答案，而value为对应的分数。
    """
    Q1, Q2, P1, P2 = [], [], [], []
    # 问题
    q_text_words = tokenize(q_text)
    q_text = ''.join(q_text_words)
    qid = [char2id.get(c, 1) for c in q_text]
    for i, p_text in enumerate(p_texts):
        # 篇章
        p_text_words = tokenize(p_text)
        p_text = ''.join(p_text_words)
        pid = [char2id.get(c, 1) for c in p_text]
        Q1.append(qid)
        Q2.append(q_text_words)
        P1.append(pid)
        P2.append(p_text_words)
    # 给出结果序列
    Q1 = seq_padding(Q1)
    Q2 = sent2vec(Q2)
    P1 = seq_padding(P1)
    P2 = sent2vec(P2)
    A1, A2 = model.predict([Q1, Q2, P1, P2])
    # 输出每个篇章的答案
    Result = []
    for a1, a2, p in zip(A1, A2, p_texts):
        a1, a2 = a1[: len(p)], a2[: len(p)]
        l_idxs = np.where(a1 > threshold)[0]
        r_idxs = np.where(a2 > threshold)[0]
        result = {}
        for i in l_idxs:
            cond = (r_idxs >= i) & (r_idxs < i + maxlen)
            for j in r_idxs[cond]:
                k = p[i: j + 1]
                result[k] = max(result.get(k, 0), a1[i] * a2[j])
        if result:
            Result.append(result)
    # 综合所有答案
    R = {}
    for result in Result:
        for k, v in result.items():
            R[k] = R.get(k, []) + [v]
    R = {
        k: (np.array(v) ** 2).sum() / (sum(v) + 1)
        for k, v in R.items()
    }
    return R

# %%
def max_in_dict(d):
    if d:
        return sorted(d.items(), key=lambda s: -s[1])[0][0]

# %%
def predict(data, filename, threshold=0.1):
    with open(filename, 'w') as f:
        for d in tqdm(iter(data)):
            q_text = d['question']
            p_texts = [p['passage'] for p in d['passages']]
            a = extract_answer(q_text, p_texts, threshold=threshold)
            a = max_in_dict(a)
            if a and a != " ":
                s = u'%s\t%s\n' % (d['id'], a)
            else:
                s = u'%s\t%s\n' % (d['id'], '没找到答案')
            f.write(s)

# %%
def evaluate(threshold=0.01):
    predict(dev_data, 'tmp_result.txt', threshold=threshold)
    # acc, f1, final = json.loads(
    #     os.popen(
    #         r'python ../evaluate_tool/evaluate.py E:\baidu_code\dgcnn_for_reading_comprehension\dgcnn\tmp_result.txt '
    #         r'tmp_output.txt '
    #     ).read().strip()
    # )
    acc, f1, final = evaluate_acc("tmp_result.txt", "out_result.txt")
    print(acc, f1, final)
    return acc, f1, final

# %%
def evaluate_acc(input_file, output_file):
    load_qid_answer_expand("qid_answer_expand")
    total = 0
    right = 0
    sum_f = 0.0
    # 同时打开两个文件，一个文件读一个文件取
    with open(input_file, "r") as infile, open(output_file, "w") as outfile:
        infile = infile.readlines()
        print(len(infile))
        for line_message in infile:
            total += 1
            items = line_message.replace("\n", "").split("\t")
            if len(items) != 2:
                # raise ValueError(
                #     "Invalid line_message: '%s', which should have 2 fields. The 2 fields are query_id and "
                #     "competitor_answer" % line_message.strip())
                continue
            qid, competitor_answer = items
            right_flag = is_exact_match_answer(qid, competitor_answer)
            if right_flag == "1":
                right += 1
            max_f, max_f_precision, max_f_recall, max_f_answer = cacu_character_level_f(qid, competitor_answer)
            sum_f += max_f
            outfile.write("%s\t%s\t%s\t%f\t%f\t%f\t%s\n" % (
                qid, competitor_answer, right_flag, max_f, max_f_precision, max_f_recall, max_f_answer))
    print("query-level precision=%d/%d=%f" % (right, total, 1.0 * right / total))
    print("character-level average f value=%f/%f=%f" % (sum_f, total, sum_f / total))
    return 1.0 * right / total, sum_f / total, (1.0 * right / total + sum_f / total) / 2.

# %%
class Evaluate(Callback):
    def __init__(self):
        self.metrics = []
        self.best = 0.
        self.stage = 0

    def on_epoch_end(self, epoch, logs=None):
        EMAer.apply_ema_weights()
        #EMAer.me_apply_ema_weights()
        acc, f1, final = evaluate()
        print('准确率', epoch, acc, f1, final)
        self.metrics.append((epoch, acc, f1, final))
        json.dump(self.metrics, open('train.log', 'w'), indent=4)
        if final > self.best:
            self.best = final
            train_model.save_weights('best_model_weights.h5')
        print('learning rate: %s' % (K.eval(self.model.optimizer.lr)))
        print('acc: %.4f, f1: %.4f, final: %.4f, best final: %.4f\n' % (acc, f1, final, self.best))
        EMAer.reset_old_weights()
        if epoch + 1 == 30 or (
                self.stage == 0 and epoch > 15 and
                (final < 0.5 or np.argmax(self.metrics, 0)[3] < len(self.metrics) - 5)
        ):
            """
            达到30个epoch，或者final开始下降到0.5以下（开始发散），
            或者连续5个epoch都没提升，就降低学习率。
            """
            self.stage = 1
            train_model.load_weights('best_model_weights.h5')
            EMAer.initialize()
            K.set_value(self.model.optimizer.lr, 1e-4)
            K.set_value(self.model.optimizer.iterations, 0)
            opt_weights = K.batch_get_value(self.model.optimizer.weights)
            opt_weights = [w * 0. for w in opt_weights]
            K.batch_set_value(zip(self.model.optimizer.weights, opt_weights))

# %%
train_D = data_generator(train_data)
evaluator = Evaluate()

# %%
if __name__ == '__main__':
    train_model.fit_generator(train_D.__iter__(),
                              steps_per_epoch=len(train_D),
                              epochs=10,
                              callbacks=[evaluator]
                              )
else:
    train_model.load_weights('best_model_weights.h5')
# Out:
# WARNING:tensorflow:From E:\Anaconda\envs\tf_gpu_cu10\lib\site-packages\tensorflow\python\ops\math_grad.py:1205: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/10
# 641/641 [==============================] - 227s 353ms/step - loss: 0.6303
# 9938it [24:35,  6.74it/s]
# 9938
# 偏铝酸
# [b'\xe5\x81\x8f\xe9\x93\x9d\xe9\x85\xb8']
# 2
# [b'2']
# 潍坊市
# [b'\xe6\xbd\x8d\xe5\x9d\x8a\xe5\xb8\x82']
# 潮州
# [b'\xe6\xbd\xae\xe5\xb7\x9e']
# 耳塞
# [b'\xe8\x80\xb3\xe5\xa1\x9e']
# 天津大学
# [b'\xe5\xa4\xa9\xe6\xb4\xa5\xe5\xa4\xa7\xe5\xad\xa6']
# 史密斯
# [b'\xe5\x8f\xb2\xe5\xaf\x86\xe6\x96\xaf']
# 仗义
# [b'\xe4\xbb\x97\xe4\xb9\x89']
# 门德尔松
# [b'\xe9\x97\xa8\xe5\xbe\xb7\xe5\xb0\x94\xe6\x9d\xbe']
# 张禧嫔
# [b'\xe5\xbc\xa0\xe7\xa6\xa7\xe5\xab\x94']
# 内蒙古自治区
# [b'\xe5\x86\x85\xe8\x92\x99\xe5\x8f\xa4\xe8\x87\xaa\xe6\xb2\xbb\xe5\x8c\xba']
# 42
# [b'42']
# 寇准
# [b'\xe5\xaf\x87\xe5\x87\x86']
# 1949
# [b'1949']
# 中国共产党
# [b'\xe4\xb8\xad\xe5\x9b\xbd\xe5\x85\xb1\xe4\xba\xa7\xe5\x85\x9a']
# 毛泽东
# [b'\xe6\xaf\x9b\xe6\xb3\xbd\xe4\xb8\x9c']
# 顾晓君
# [b'\xe9\xa1\xbe\xe6\x99\x93\xe5\x90\x9b']
# 药酒
# [b'\xe8\x8d\xaf\xe9\x85\x92']
# 安徽
# [b'\xe5\xae\x89\xe5\xbe\xbd']
# 秦皇岛市
# [b'\xe7\xa7\xa6\xe7\x9a\x87\xe5\xb2\x9b\xe5\xb8\x82']
# 浙江
# [b'\xe6\xb5\x99\xe6\xb1\x9f']
# 汪若海
# [b'\xe6\xb1\xaa\xe8\x8b\xa5\xe6\xb5\xb7']
# 惠安县
# [b'\xe6\x83\xa0\xe5\xae\x89\xe5\x8e\xbf']
# 猪
# [b'\xe7\x8c\xaa']
# 铁岭市
# [b'\xe9\x93\x81\xe5\xb2\xad\xe5\xb8\x82']
# 7画
# [b'7\xe7\x94\xbb']
# 京张
# [b'\xe4\xba\xac\xe5\xbc\xa0']
# 二桃杀三士
# [b'\xe4\xba\x8c\xe6\xa1\x83\xe6\x9d\x80\xe4\xb8\x89\xe5\xa3\xab']
# 财政局
# [b'\xe8\xb4\xa2\xe6\x94\xbf\xe5\xb1\x80']
# 佟大为
# [b'\xe4\xbd\x9f\xe5\xa4\xa7\xe4\xb8\xba']
# 三种
# [b'\xe4\xb8\x89\xe7\xa7\x8d']
# 杭州
# [b'\xe6\x9d\xad\xe5\xb7\x9e']
# 京剧
# [b'\xe4\xba\xac\xe5\x89\xa7']
# 绝地
# [b'\xe7\xbb\x9d\xe5\x9c\xb0']
# 2
# [b'2']
# 兴业银行
# [b'\xe5\x85\xb4\xe4\xb8\x9a\xe9\x93\xb6\xe8\xa1\x8c']
# 蜡梅
# [b'\xe8\x9c\xa1\xe6\xa2\x85']
# IU
# [b'iu']
# 柚子
# [b'\xe6\x9f\x9a\xe5\xad\x90']
# 河北省
# [b'\xe6\xb2\xb3\xe5\x8c\x97\xe7\x9c\x81']
# 两个
# [b'\xe4\xb8\xa4\xe4\xb8\xaa']
# 黑寡妇
# [b'\xe9\xbb\x91\xe5\xaf\xa1\xe5\xa6\x87']
# 班固
# [b'\xe7\x8f\xad\xe5\x9b\xba']
# 中华人民共和国
# [b'\xe4\xb8\xad\xe5\x8d\x8e\xe4\xba\xba\xe6\xb0\x91\xe5\x85\xb1\xe5\x92\x8c\xe5\x9b\xbd']
# 波特
# [b'\xe6\xb3\xa2\xe7\x89\xb9']
# 张若虚
# [b'\xe5\xbc\xa0\xe8\x8b\xa5\xe8\x99\x9a']
# 泰国
# [b'\xe6\xb3\xb0\xe5\x9b\xbd']
# 广西
# [b'\xe5\xb9\xbf\xe8\xa5\xbf']
# 脐
# [b'\xe8\x84\x90']
# 王
# [b'\xe7\x8e\x8b']
# 王嘉尔
# [b'\xe7\x8e\x8b\xe5\x98\x89\xe5\xb0\x94']
# 毫克
# [b'\xe6\xaf\xab\xe5\x85\x8b']
# 长江
# [b'\xe9\x95\xbf\xe6\xb1\x9f']
# 乔治
# [b'\xe4\xb9\x94\xe6\xb2\xbb']
# 毛晓彤
# [b'\xe6\xaf\x9b\xe6\x99\x93\xe5\xbd\xa4']
# 包文婧
# [b'\xe5\x8c\x85\xe6\x96\x87\xe5\xa9\xa7']
# 军区
# [b'\xe5\x86\x9b\xe5\x8c\xba']
# 级
# [b'\xe7\xba\xa7']
# 蜘蛛侠
# [b'\xe8\x9c\x98\xe8\x9b\x9b\xe4\xbe\xa0']
# 11
# [b'11']
# 李沁
# [b'\xe6\x9d\x8e\xe6\xb2\x81']
# 区
# [b'\xe5\x8c\xba']
# 53
# [b'53']
# 手足口病
# [b'\xe6\x89\x8b\xe8\xb6\xb3\xe5\x8f\xa3\xe7\x97\x85']
# 工伤
# [b'\xe5\xb7\xa5\xe4\xbc\xa4']
# 双色球
# [b'\xe5\x8f\x8c\xe8\x89\xb2\xe7\x90\x83']
# 淮阴
# [b'\xe6\xb7\xae\xe9\x98\xb4']
# 李白
# [b'\xe6\x9d\x8e\xe7\x99\xbd']
# 笑笑星儿
# [b'\xe7\xac\x91\xe7\xac\x91\xe6\x98\x9f\xe5\x84\xbf']
# 台北
# [b'\xe5\x8f\xb0\xe5\x8c\x97']
# 王维
# [b'\xe7\x8e\x8b\xe7\xbb\xb4']
# 葡萄牙人
# [b'\xe8\x91\xa1\xe8\x90\x84\xe7\x89\x99\xe4\xba\xba']
# 珊
# [b'\xe7\x8f\x8a']
# 王卡
# [b'\xe7\x8e\x8b\xe5\x8d\xa1']
# 两次
# [b'\xe4\xb8\xa4\xe6\xac\xa1']
# 5天
# [b'5\xe5\xa4\xa9']
# 广西自治区
# [b'\xe5\xb9\xbf\xe8\xa5\xbf\xe8\x87\xaa\xe6\xb2\xbb\xe5\x8c\xba']
# 保山
# [b'\xe4\xbf\x9d\xe5\xb1\xb1']
# 河南
# [b'\xe6\xb2\xb3\xe5\x8d\x97']
# B
# [b'b']
# 位
# [b'\xe4\xbd\x8d']
# 仪器
# [b'\xe4\xbb\xaa\xe5\x99\xa8']
# 江西
# [b'\xe6\xb1\x9f\xe8\xa5\xbf']
# 娜美
# [b'\xe5\xa8\x9c\xe7\xbe\x8e']
# 吴尊
# [b'\xe5\x90\xb4\xe5\xb0\x8a']
# 台风
# [b'\xe5\x8f\xb0\xe9\xa3\x8e']
# 杠杆
# [b'\xe6\x9d\xa0\xe6\x9d\x86']
# 羟基
# [b'\xe7\xbe\x9f\xe5\x9f\xba']
# 彭丽媛
# [b'\xe5\xbd\xad\xe4\xb8\xbd\xe5\xaa\x9b']
# 漳州
# [b'\xe6\xbc\xb3\xe5\xb7\x9e']
# 甘肃政法学院
# [b'\xe7\x94\x98\xe8\x82\x83\xe6\x94\xbf\xe6\xb3\x95\xe5\xad\xa6\xe9\x99\xa2']
# 兴化市
# [b'\xe7\x99\xbd\xe5\xad\x90']
# 深州市
# [b'\xe6\xb7\xb1\xe5\xb7\x9e\xe5\xb8\x82']
# 陈抟
# [b'\xe9\x99\x88\xe6\x8a\x9f']
# 42
# [b'42']
# 昆虫
# [b'\xe6\x98\x86\xe8\x99\xab']
# 英国
# [b'\xe8\x8b\xb1\xe5\x9b\xbd']
# 朝阳区
# [b'\xe6\x9c\x9d\xe9\x98\xb3\xe5\x8c\xba']
# 山西
# [b'\xe5\xb1\xb1\xe8\xa5\xbf']
# 桶
# [b'\xe6\xa1\xb6']
# 2
# [b'2']
# 加斯
# [b'\xe5\x8a\xa0\xe6\x96\xaf']
# 安顺
# [b'\xe5\xae\x89\xe9\xa1\xba']
# 3
# [b'3']
# 江城大道
# [b'\xe6\xb1\x9f\xe5\x9f\x8e\xe5\xa4\xa7\xe9\x81\x93']
# 安德鲁
# [b'\xe5\xae\x89\xe5\xbe\xb7\xe9\xb2\x81']
# 555
# [b'555']
# 资生堂
# [b'\xe8\xb5\x84\xe7\x94\x9f\xe5\xa0\x82']
# 麦哲伦
# [b'\xe9\xba\xa6\xe5\x93\xb2\xe4\xbc\xa6']
# 皇冠
# [b'\xe7\x9a\x87\xe5\x86\xa0']
# 张涵予
# [b'\xe5\xbc\xa0\xe6\xb6\xb5\xe4\xba\x88']
# 分升
# [b'\xe5\x88\x86\xe5\x8d\x87']
# SV
# [b'sv']
# 温家宝
# [b'\xe6\xb8\xa9\xe5\xae\xb6\xe5\xae\x9d']
# 济南军区
# [b'\xe6\xb5\x8e\xe5\x8d\x97\xe5\x86\x9b\xe5\x8c\xba']
# 1
# [b'1']
# 金香玉
# [b'\xe9\x87\x91\xe9\xa6\x99\xe7\x8e\x89']
# 变压器
# [b'\xe5\x8f\x98\xe5\x8e\x8b\xe5\x99\xa8']
# 美国
# [b'\xe7\xbe\x8e\xe5\x9b\xbd']
# 四根刺
# [b'\xe5\x9b\x9b\xe6\xa0\xb9\xe5\x88\xba']
# 安阳
# [b'\xe5\xae\x89\xe9\x98\xb3']
# 中关村
# [b'\xe4\xb8\xad\xe5\x85\xb3\xe6\x9d\x91']
# 夜上海
# [b'\xe5\xa4\x9c\xe4\xb8\x8a\xe6\xb5\xb7']
# 天秤座
# [b'\xe5\xa4\xa9\xe7\xa7\xa4\xe5\xba\xa7']
# 经线
# [b'\xe7\xbb\x8f\xe7\xba\xbf']
# 1.5
# [b'1', b'5']
# 图尔
# [b'\xe5\x9b\xbe\xe5\xb0\x94']
# 华融
# [b'\xe5\x8d\x8e\xe8\x9e\x8d']
# 爵迹
# [b'\xe7\x88\xb5\xe8\xbf\xb9']
# 长安
# [b'\xe9\x95\xbf\xe5\xae\x89']
# 雨燕
# [b'\xe9\x9b\xa8\xe7\x87\x95']
# 舟山
# [b'\xe8\x88\x9f\xe5\xb1\xb1']
# 马耀祖
# [b'\xe9\xa9\xac\xe8\x80\x80\xe7\xa5\x96']
# 克
# [b'\xe5\x85\x8b']
# 西伯利亚
# [b'\xe8\xa5\xbf\xe4\xbc\xaf\xe5\x88\xa9\xe4\xba\x9a']
# 120
# [b'120']
# 韩国
# [b'\xe9\x9f\xa9\xe5\x9b\xbd']
# 三角形
# [b'\xe4\xb8\x89\xe8\xa7\x92\xe5\xbd\xa2']
# 长沙
# [b'\xe9\x95\xbf\xe6\xb2\x99']
# 中央党校
# [b'\xe4\xb8\xad\xe5\xa4\xae\xe5\x85\x9a\xe6\xa0\xa1']
# 大象
# [b'\xe5\xa4\xa7\xe8\xb1\xa1']
# 吉利
# [b'\xe5\x90\x89\xe5\x88\xa9']
# 管理学
# [b'\xe7\xae\xa1\xe7\x90\x86\xe5\xad\xa6']
# 13
# [b'13']
# 陆良
# [b'\xe9\x99\x86\xe8\x89\xaf']
# 王姿允
# [b'\xe7\x8e\x8b\xe5\xa7\xbf\xe5\x85\x81']
# 迪拜
# [b'\xe8\xbf\xaa\xe6\x8b\x9c']
# 顾闳中
# [b'\xe9\xa1\xbe\xe9\x97\xb3\xe4\xb8\xad']
# 二炮
# [b'\xe4\xba\x8c\xe7\x82\xae']
# 安徽
# [b'\xe5\xae\x89\xe5\xbe\xbd']
# u
# [b'u']
# 轮胎
# [b'\xe8\xbd\xae\xe8\x83\x8e']
# 安徽省
# [b'\xe5\xae\x89\xe5\xbe\xbd\xe7\x9c\x81']
# 三义
# [b'\xe4\xb8\x89\xe4\xb9\x89']
# B
# [b'b']
# R7
# [b'r7']
# 汉高祖刘邦
# [b'\xe6\xb1\x89\xe9\xab\x98\xe7\xa5\x96\xe5\x88\x98\xe9\x82\xa6']
# 甘德
# [b'\xe7\x94\x98\xe5\xbe\xb7']
# John
# [b'john']
# 蒯
# [b'\xe8\x92\xaf']
# 2
# [b'2']
# 司马迁
# [b'\xe5\x8f\xb8\xe9\xa9\xac\xe8\xbf\x81']
# 2
# [b'2']
# 口喷人
# [b'\xe5\x8f\xa3\xe5\x96\xb7\xe4\xba\xba']
# 广州
# [b'\xe5\xb9\xbf\xe5\xb7\x9e']
# 川纯子
# [b'\xe5\xb7\x9d\xe7\xba\xaf\xe5\xad\x90']
# 周
# [b'\xe5\x91\xa8']
# 湖南
# [b'\xe6\xb9\x96\xe5\x8d\x97']
# 46
# [b'46']
# 阿根廷
# [b'\xe9\x98\xbf\xe6\xa0\xb9\xe5\xbb\xb7']
# 第一
# [b'\xe7\xac\xac\xe4\xb8\x80']
# 奥迪
# [b'\xe5\xa5\xa5\xe8\xbf\xaa']
# 黑瞎子岛
# [b'\xe9\xbb\x91\xe7\x9e\x8e\xe5\xad\x90\xe5\xb2\x9b']
# D
# [b'd']
# 山东省
# [b'\xe5\xb1\xb1\xe4\xb8\x9c\xe7\x9c\x81']
# 江苏省
# [b'\xe6\xb1\x9f\xe8\x8b\x8f\xe7\x9c\x81']
# 湖南省
# [b'\xe6\xb9\x96\xe5\x8d\x97\xe7\x9c\x81']
# 伊朗
# [b'\xe4\xbc\x8a\xe6\x9c\x97']
# 延边
# [b'\xe5\xbb\xb6\xe8\xbe\xb9']
# 张晓风
# [b'\xe5\xbc\xa0\xe6\x99\x93\xe9\xa3\x8e']
# 刘涛
# [b'\xe5\x88\x98\xe6\xb6\x9b']
# 大黄蜂
# [b'\xe5\xa4\xa7\xe9\xbb\x84\xe8\x9c\x82']
# 哥
# [b'\xe5\x93\xa5']
# 无限极
# [b'\xe6\x97\xa0\xe9\x99\x90\xe6\x9e\x81']
# 迪丽热巴
# [b'\xe8\xbf\xaa\xe4\xb8\xbd\xe7\x83\xad\xe5\xb7\xb4']
# 匹马
# [b'\xe5\x8c\xb9\xe9\xa9\xac']
# 浙江
# [b'\xe6\xb5\x99\xe6\xb1\x9f']
# 江铠
# [b'\xe6\xb1\x9f\xe9\x93\xa0']
# 浙江省
# [b'\xe6\xb5\x99\xe6\xb1\x9f\xe7\x9c\x81']
# 路飞
# [b'\xe8\xb7\xaf\xe9\xa3\x9e']
# 宋濂
# [b'\xe5\xae\x8b\xe6\xbf\x82']
# 五台山
# [b'\xe4\xba\x94\xe5\x8f\xb0\xe5\xb1\xb1']
# 教育
# [b'\xe6\x95\x99\xe8\x82\xb2']
# 激光
# [b'\xe6\xbf\x80\xe5\x85\x89']
# 暴雪
# [b'\xe6\x9a\xb4\xe9\x9b\xaa']
# 可好
# [b'\xe5\x8f\xaf\xe5\xa5\xbd']
# 头孢
# [b'\xe5\xa4\xb4\xe5\xad\xa2']
# 叉
# [b'\xe5\x8f\x89']
# 苏轼
# [b'\xe8\x8b\x8f\xe8\xbd\xbc']
# 成都
# [b'\xe6\x88\x90\xe9\x83\xbd']
# 邬君梅
# [b'\xe9\x82\xac\xe5\x90\x9b\xe6\xa2\x85']
# 粉红
# [b'\xe7\xb2\x89\xe7\xba\xa2']
# 绿野仙踪
# [b'\xe7\xbb\xbf\xe9\x87\x8e\xe4\xbb\x99\xe8\xb8\xaa']
# 换
# [b'\xe6\x8d\xa2']
# 刺猬
# [b'\xe5\x88\xba\xe7\x8c\xac']
# 20
# [b'20']
# 个啷
# [b'\xe4\xb8\xaa\xe5\x95\xb7']
# 西气东
# [b'\xe8\xa5\xbf\xe6\xb0\x94\xe4\xb8\x9c']
# 汕头市
# [b'\xe6\xb1\x95\xe5\xa4\xb4\xe5\xb8\x82']
# 德国
# [b'\xe5\xbe\xb7\xe5\x9b\xbd']
# 中国
# [b'\xe4\xb8\xad\xe5\x9b\xbd']
# 长沙
# [b'\xe9\x95\xbf\xe6\xb2\x99']
# 澳门
# [b'\xe6\xbe\xb3\xe9\x97\xa8']
# 神舟
# [b'\xe7\xa5\x9e\xe8\x88\x9f']
# 二
# [b'\xe4\xba\x8c']
# 区
# [b'\xe5\x8c\xba']
# 缙云县
# [b'\xe7\xbc\x99\xe4\xba\x91\xe5\x8e\xbf']
# 连云港
# [b'\xe8\xbf\x9e\xe4\xba\x91\xe6\xb8\xaf']
# 乱世王者先帝试炼
# [b'\xe4\xb9\xb1\xe4\xb8\x96\xe7\x8e\x8b\xe8\x80\x85\xe5\x85\x88\xe5\xb8\x9d\xe8\xaf\x95\xe7\x82\xbc']
# 吕飞
# 晋城
# [b'\xe6\x99\x8b\xe5\x9f\x8e']
# 油
# [b'\xe6\xb2\xb9']
# 柳永
# [b'\xe6\x9f\xb3\xe6\xb0\xb8']
# 日本
# [b'\xe6\x97\xa5\xe6\x9c\xac']
# 威尔士
# [b'\xe5\xa8\x81\xe5\xb0\x94\xe5\xa3\xab']
# 邛崃市
# [b'\xe9\x82\x9b\xe5\xb4\x83\xe5\xb8\x82']
# 施特劳斯
# [b'\xe6\x96\xbd\xe7\x89\xb9\xe5\x8a\xb3\xe6\x96\xaf']
# 12
# [b'12']
# 郑州
# [b'\xe9\x83\x91\xe5\xb7\x9e']
# 麻雀
# [b'\xe9\xba\xbb\xe9\x9b\x80']
# 张自忠
# [b'\xe5\xbc\xa0\xe8\x87\xaa\xe5\xbf\xa0']
# 黄灿灿
# [b'\xe9\xbb\x84\xe7\x81\xbf\xe7\x81\xbf']
# 李钟硕
# [b'\xe6\x9d\x8e\xe9\x92\x9f\xe7\xa1\x95']
# 湖南
# [b'\xe6\xb9\x96\xe5\x8d\x97']
# 春节
# [b'\xe6\x98\xa5\xe8\x8a\x82']
# 张宇菲
# [b'\xe5\xbc\xa0\xe5\xae\x87\xe8\x8f\xb2']
# 西南政法大学
# [b'\xe8\xa5\xbf\xe5\x8d\x97\xe6\x94\xbf\xe6\xb3\x95\xe5\xa4\xa7\xe5\xad\xa6']
# 严屹宽
# [b'\xe4\xb8\xa5\xe5\xb1\xb9\xe5\xae\xbd']
# 四川
# [b'\xe5\x9b\x9b\xe5\xb7\x9d']
# 郴州
# [b'\xe9\x83\xb4\xe5\xb7\x9e']
# 英国
# [b'\xe8\x8b\xb1\xe5\x9b\xbd']
# 雁塔区
# [b'\xe9\x9b\x81\xe5\xa1\x94\xe5\x8c\xba']
# 成都
# [b'\xe6\x88\x90\xe9\x83\xbd']
# 南京
# [b'\xe5\x8d\x97\xe4\xba\xac']
# 宪法
# [b'\xe5\xae\xaa\xe6\xb3\x95']
# 亚细亚
# [b'\xe4\xba\x9a\xe7\xbb\x86\xe4\xba\x9a']
# 一
# [b'\xe4\xb8\x80']
# 三溪
# [b'\xe4\xb8\x89\xe6\xba\xaa']
# 无花果
# [b'\xe6\x97\xa0\xe8\x8a\xb1\xe6\x9e\x9c']
# 七月
# [b'\xe4\xb8\x83\xe6\x9c\x88']
# 烟台
# [b'\xe7\x83\x9f\xe5\x8f\xb0']
# 大调
# [b'\xe5\xa4\xa7\xe8\xb0\x83']
# 广东省
# [b'\xe5\xb9\xbf\xe4\xb8\x9c\xe7\x9c\x81']
# 嬴政
# [b'\xe5\xac\xb4\xe6\x94\xbf']
# 整数
# [b'\xe6\x95\xb4\xe6\x95\xb0']
# 王刚
# [b'\xe7\x8e\x8b\xe5\x88\x9a']
# 北京
# [b'\xe5\x8c\x97\xe4\xba\xac']
# 15
# [b'15']
# 庄换羽
# [b'\xe5\xba\x84\xe6\x8d\xa2\xe7\xbe\xbd']
# 迪迦
# [b'\xe8\xbf\xaa\xe8\xbf\xa6']
# 公租房
# [b'\xe8\x85\x8a\xe6\x9c\x88\xe4\xba\x8c\xe5\x8d\x81\xe5\x85\xab']
# 云南
# [b'\xe4\xba\x91\xe5\x8d\x97']
# 哈密
# [b'\xe5\x93\x88\xe5\xaf\x86']
# 洋葱
# [b'\xe6\xb4\x8b\xe8\x91\xb1']
# 染色体
# [b'\xe6\x9f\x93\xe8\x89\xb2\xe4\xbd\x93']
# 伊犁
# [b'\xe4\xbc\x8a\xe7\x8a\x81']
# 西班牙
# [b'\xe8\xa5\xbf\xe7\x8f\xad\xe7\x89\x99']
# 德国
# [b'\xe5\xbe\xb7\xe5\x9b\xbd']
# 掉期
# [b'\xe6\x8e\x89\xe6\x9c\x9f']
# 第四笔
# [b'\xe7\xac\xac\xe5\x9b\x9b\xe7\xac\x94']
# 林正英
# [b'\xe6\x9e\x97\xe6\xad\xa3\xe8\x8b\xb1']
# 2
# [b'2']
# 云南迪庆
# [b'\xe4\xba\x91\xe5\x8d\x97\xe8\xbf\xaa\xe5\xba\x86']
# 鹰潭市
# [b'\xe9\xb9\xb0\xe6\xbd\xad\xe5\xb8\x82']
# 肖小军
# [b'\xe8\x82\x96\xe5\xb0\x8f\xe5\x86\x9b']
# 96
# [b'96']
# 绝对值
# [b'\xe7\xbb\x9d\xe5\xaf\xb9\xe5\x80\xbc']
# 欧姆
# [b'\xe6\xac\xa7\xe5\xa7\x86']
# 普陀区
# [b'\xe6\x99\xae\xe9\x99\x80\xe5\x8c\xba']
# 科伦坡
# [b'\xe7\xa7\x91\xe4\xbc\xa6\xe5\x9d\xa1']
# 钱学森
# [b'\xe9\x92\xb1\xe5\xad\xa6\xe6\xa3\xae']
# 以色列
# [b'\xe4\xbb\xa5\xe8\x89\xb2\xe5\x88\x97']
# 孙红雷
# [b'\xe5\xad\x99\xe7\xba\xa2\xe9\x9b\xb7']
# 许昌
# [b'\xe8\xae\xb8\xe6\x98\x8c']
# 华为
# [b'\xe5\x8d\x8e\xe4\xb8\xba']
# 广州军区
# [b'\xe5\xb9\xbf\xe5\xb7\x9e\xe5\x86\x9b\xe5\x8c\xba']
# 6
# [b'6']
# 张仪
# [b'\xe5\xbc\xa0\xe4\xbb\xaa']
# 猴脑
# [b'\xe7\x8c\xb4\xe8\x84\x91']
# 耐克
# [b'\xe8\x80\x90\xe5\x85\x8b']
# 庄子
# [b'\xe5\xba\x84\xe5\xad\x90']
# 毛里塔尼亚
# [b'\xe6\xaf\x9b\xe9\x87\x8c\xe5\xa1\x94\xe5\xb0\xbc\xe4\xba\x9a']
# 锡山区
# [b'\xe9\x94\xa1\xe5\xb1\xb1\xe5\x8c\xba']
# 髋关节
# [b'\xe9\xab\x8b\xe5\x85\xb3\xe8\x8a\x82']
# 异亮氨酸
# [b'\xe5\xbc\x82\xe4\xba\xae\xe6\xb0\xa8\xe9\x85\xb8']
# 利齿撕咬
# [b'\xe5\x88\xa9\xe9\xbd\xbf\xe6\x92\x95\xe5\x92\xac']
# 44亿
# [b'44\xe4\xba\xbf']
# 2.38
# [b'2', b'38']
# 豆蔻
# [b'\xe8\xb1\x86\xe8\x94\xbb']
# 辽宁省
# [b'\xe8\xbe\xbd\xe5\xae\x81\xe7\x9c\x81']
# 染色体
# [b'\xe6\x9f\x93\xe8\x89\xb2\xe4\xbd\x93']
# 20
# [b'20']
# PUMP
# [b'pump']
# 拜伦
# [b'\xe6\x8b\x9c\xe4\xbc\xa6']
# 中国共产党
# [b'\xe4\xb8\xad\xe5\x9b\xbd\xe5\x85\xb1\xe4\xba\xa7\xe5\x85\x9a']
# 刘翔
# [b'\xe5\x88\x98\xe7\xbf\x94']
# 刘飞
# [b'\xe5\x88\x98\xe9\xa3\x9e']
# 白色
# [b'\xe7\x99\xbd\xe8\x89\xb2']
# 木叶
# [b'\xe6\x9c\xa8\xe5\x8f\xb6']
# 意大利
# [b'\xe6\x84\x8f\xe5\xa4\xa7\xe5\x88\xa9']
# 岳云鹏
# [b'\xe5\xb2\xb3\xe4\xba\x91\xe9\xb9\x8f']
# 陈独秀
# [b'\xe9\x99\x88\xe7\x8b\xac\xe7\xa7\x80']
# 表
# [b'\xe8\xa1\xa8']
# 四
# [b'\xe5\x9b\x9b']
# 凤九
# [b'\xe5\x87\xa4\xe4\xb9\x9d']
# 生肖
# [b'\xe7\x94\x9f\xe8\x82\x96']
# 省
# [b'\xe7\x9c\x81']
# 补钙
# [b'\xe8\xa1\xa5\xe9\x92\x99']
# 雷凌
# [b'\xe9\x9b\xb7\xe5\x87\x8c']
# 浙江省
# [b'\xe6\xb5\x99\xe6\xb1\x9f\xe7\x9c\x81']
# 封神演义
# [b'\xe5\xb0\x81\xe7\xa5\x9e\xe6\xbc\x94\xe4\xb9\x89']
# 三国演义
# [b'\xe4\xb8\x89\xe5\x9b\xbd\xe6\xbc\x94\xe4\xb9\x89']
# 十里桃花
# [b'\xe5\x8d\x81\xe9\x87\x8c\xe6\xa1\x83\xe8\x8a\xb1']
# 醉玲珑
# [b'\xe9\x86\x89\xe7\x8e\xb2\xe7\x8f\x91']
# 王源
# [b'\xe7\x8e\x8b\xe6\xba\x90']
# 天干
# [b'\xe5\xa4\xa9\xe5\xb9\xb2']
# 16
# [b'16']
# 高唐县
# [b'\xe9\xab\x98\xe5\x94\x90\xe5\x8e\xbf']
# 厦门
# [b'\xe5\x8e\xa6\xe9\x97\xa8']
# ank
# [b'ank']
# 诸葛亮
# [b'\xe8\xaf\xb8\xe8\x91\x9b\xe4\xba\xae']
# 刘德华
# [b'\xe5\x88\x98\xe5\xbe\xb7\xe5\x8d\x8e']
# 腾冲
# [b'\xe8\x85\xbe\xe5\x86\xb2']
# 教育局
# [b'\xe6\x95\x99\xe8\x82\xb2\xe5\xb1\x80']
# 通天狄仁杰
# [b'\xe9\x80\x9a\xe5\xa4\xa9\xe7\x8b\x84\xe4\xbb\x81\xe6\x9d\xb0']
# 王丽坤
# [b'\xe7\x8e\x8b\xe4\xb8\xbd\xe5\x9d\xa4']
# 袁姗姗
# [b'\xe8\xa2\x81\xe5\xa7\x97\xe5\xa7\x97']
# 古巴
# [b'\xe5\x8f\xa4\xe5\xb7\xb4']
# 蓝色
# [b'\xe8\x93\x9d\xe8\x89\xb2']
# 紫禁之巅
# [b'\xe7\xb4\xab\xe7\xa6\x81\xe4\xb9\x8b\xe5\xb7\x85']
# 贵州省
# [b'\xe8\xb4\xb5\xe5\xb7\x9e\xe7\x9c\x81']
# 江西
# [b'\xe6\xb1\x9f\xe8\xa5\xbf']
# 周润发
# [b'\xe5\x91\xa8\xe6\xb6\xa6\xe5\x8f\x91']
# 梁文音
# [b'\xe6\xa2\x81\xe6\x96\x87\xe9\x9f\xb3']
# 德国
# [b'\xe5\xbe\xb7\xe5\x9b\xbd']
# 童子
# [b'\xe7\xab\xa5\xe5\xad\x90']
# 肿瘤君
# [b'\xe8\x82\xbf\xe7\x98\xa4\xe5\x90\x9b']
# 墨水
# [b'\xe5\xa2\xa8\xe6\xb0\xb4']
# 清朝
# [b'\xe6\xb8\x85\xe6\x9c\x9d']
# 徐璐
# [b'\xe5\xbe\x90\xe7\x92\x90']
# 陆风
# [b'\xe9\x99\x86\xe9\xa3\x8e']
# 黄鹂
# [b'\xe9\xbb\x84\xe9\xb9\x82']
# 巴西
# [b'\xe5\xb7\xb4\xe8\xa5\xbf']
# 50
# [b'50']
# 香蕉
# [b'\xe9\xa6\x99\xe8\x95\x89']
# 杜维
# [b'\xe6\x9d\x9c\xe7\xbb\xb4']
# 花千骨
# [b'\xe8\x8a\xb1\xe5\x8d\x83\xe9\xaa\xa8']
# 帝豪
# [b'\xe5\xb8\x9d\xe8\xb1\xaa']
# 邓演达
# [b'\xe9\x82\x93\xe6\xbc\x94\xe8\xbe\xbe']
# 刘禅
# [b'\xe5\x88\x98\xe7\xa6\x85']
# 兴平市
# [b'\xe5\x85\xb4\xe5\xb9\xb3\xe5\xb8\x82']
# 皮皮虾
# [b'\xe7\x9a\xae\xe7\x9a\xae\xe8\x99\xbe']
# 郭艾伦
# [b'\xe9\x83\xad\xe8\x89\xbe\xe4\xbc\xa6']
# 45
# [b'45']
# 世间情
# [b'\xe4\xb8\x96\xe9\x97\xb4\xe6\x83\x85']
# 商朝
# [b'\xe5\x95\x86\xe6\x9c\x9d']
# 级
# [b'\xe7\xba\xa7']
# 月
# [b'\xe6\x9c\x88']
# 个
# [b'\xe4\xb8\xaa']
# 岳飞
# [b'\xe5\xb2\xb3\xe9\xa3\x9e']
# 唐朝
# [b'\xe5\x94\x90\xe6\x9c\x9d']
# 屈原
# [b'\xe5\xb1\x88\xe5\x8e\x9f']
# 5
# [b'5']
# 16
# [b'16']
# 大师兄
# [b'\xe5\xa4\xa7\xe5\xb8\x88\xe5\x85\x84']
# 济南
# [b'\xe6\xb5\x8e\xe5\x8d\x97']
# 柴鸡
# [b'\xe6\x9f\xb4\xe9\xb8\xa1']
# 桂林
# [b'\xe6\xa1\x82\xe6\x9e\x97']
# 萧芳芳
# [b'\xe8\x90\xa7\xe8\x8a\xb3\xe8\x8a\xb3']
# 文明
# [b'\xe6\x96\x87\xe6\x98\x8e']
# 中国
# [b'\xe4\xb8\xad\xe5\x9b\xbd']
# 冰红茶
# [b'\xe5\x86\xb0\xe7\xba\xa2\xe8\x8c\xb6']
# 长生殿
# [b'\xe9\x95\xbf\xe7\x94\x9f\xe6\xae\xbf']
# 蓝鲸
# [b'\xe8\x93\x9d\xe9\xb2\xb8']
# 激素
# [b'\xe6\xbf\x80\xe7\xb4\xa0']
# 襄阳
# [b'\xe8\xa5\x84\xe9\x98\xb3']
# 越南
# [b'\xe8\xb6\x8a\xe5\x8d\x97']
# 1
# [b'1']
# 安徽
# [b'\xe5\xae\x89\xe5\xbe\xbd']
# 静妃
# [b'\xe9\x9d\x99\xe5\xa6\x83']
# 少校
# [b'\xe5\xb0\x91\xe6\xa0\xa1']
# 香港
# [b'\xe9\xa6\x99\xe6\xb8\xaf']
# 法国
# [b'\xe6\xb3\x95\xe5\x9b\xbd']
# 天心区
# [b'\xe5\xa4\xa9\xe5\xbf\x83\xe5\x8c\xba']
# 运河
# [b'\xe8\xbf\x90\xe6\xb2\xb3']
# 南昌
# [b'\xe5\x8d\x97\xe6\x98\x8c']
# 台州
# [b'\xe5\x8f\xb0\xe5\xb7\x9e']
# 郑州
# [b'\xe9\x83\x91\xe5\xb7\x9e']
# 色
# [b'\xe8\x89\xb2']
# 雅诗兰黛
# [b'\xe9\x9b\x85\xe8\xaf\x97\xe5\x85\xb0\xe9\xbb\x9b']
# 月
# [b'\xe6\x9c\x88']
# 骈
# [b'\xe9\xaa\x88']
# 刘备
# [b'\xe5\x88\x98\xe5\xa4\x87']
# 范冰冰
# [b'\xe8\x8c\x83\xe5\x86\xb0\xe5\x86\xb0']
# 成都
# [b'\xe6\x88\x90\xe9\x83\xbd']
# 山东
# [b'\xe5\xb1\xb1\xe4\xb8\x9c']
# 博格斯
# [b'\xe5\x8d\x9a\xe6\xa0\xbc\xe6\x96\xaf']
# 三峡
# [b'\xe4\xb8\x89\xe5\xb3\xa1']
# 俄国
# [b'\xe4\xbf\x84\xe5\x9b\xbd']
# 冯远征
# [b'\xe5\x86\xaf\xe8\xbf\x9c\xe5\xbe\x81']
# 和尚
# [b'\xe5\x92\x8c\xe5\xb0\x9a']
# 周长
# [b'\xe5\x91\xa8\xe9\x95\xbf']
# 植物
# [b'\xe6\xa4\x8d\xe7\x89\xa9']
# 泰安
# [b'\xe6\xb3\xb0\xe5\xae\x89']
# 巨兽
# [b'\xe5\xb7\xa8\xe5\x85\xbd']
# 沙宝亮
# [b'\xe6\xb2\x99\xe5\xae\x9d\xe4\xba\xae']
# 绿化祖国
# [b'\xe7\xbb\xbf\xe5\x8c\x96\xe7\xa5\x96\xe5\x9b\xbd']
# 高圆圆
# [b'\xe9\xab\x98\xe5\x9c\x86\xe5\x9c\x86']
# 粽子
# [b'\xe7\xb2\xbd\xe5\xad\x90']
# 朝鲜
# [b'\xe6\x9c\x9d\xe9\xb2\x9c']
# 黄流
# [b'\xe9\xbb\x84\xe6\xb5\x81']
# 一次
# [b'\xe4\xb8\x80\xe6\xac\xa1']
# 郭敬明
# [b'\xe9\x83\xad\xe6\x95\xac\xe6\x98\x8e']
# 关羽
# [b'\xe5\x85\xb3\xe7\xbe\xbd']
# 1990
# [b'1990']
# 霍元甲
# [b'\xe9\x9c\x8d\xe5\x85\x83\xe7\x94\xb2']
# 海城区
# [b'\xe6\xb5\xb7\xe5\x9f\x8e\xe5\x8c\xba']
# 梁文音
# [b'\xe6\xa2\x81\xe6\x96\x87\xe9\x9f\xb3']
# 福建
# [b'\xe7\xa6\x8f\xe5\xbb\xba']
# 闵行区
# [b'\xe9\x97\xb5\xe8\xa1\x8c\xe5\x8c\xba']
# 河南省
# [b'\xe6\xb2\xb3\xe5\x8d\x97\xe7\x9c\x81']
# 祁东县
# [b'\xe7\xa5\x81\xe4\xb8\x9c\xe5\x8e\xbf']
# 贵州省
# [b'\xe8\xb4\xb5\xe5\xb7\x9e\xe7\x9c\x81']
# 石门县人民医院
# [b'\xe7\x9f\xb3\xe9\x97\xa8\xe5\x8e\xbf\xe4\xba\xba\xe6\xb0\x91\xe5\x8c\xbb\xe9\x99\xa2']
# 北京
# [b'\xe5\x8c\x97\xe4\xba\xac']
# 伦敦
# [b'\xe4\xbc\xa6\xe6\x95\xa6']
# 永济
# [b'\xe6\xb0\xb8\xe6\xb5\x8e']
# 韩国
# [b'\xe9\x9f\xa9\xe5\x9b\xbd']
# 亳州市
# [b'\xe4\xba\xb3\xe5\xb7\x9e\xe5\xb8\x82']
# 张钧甯
# [b'\xe5\xbc\xa0\xe9\x92\xa7\xe7\x94\xaf']
# 双色球
# [b'\xe5\x8f\x8c\xe8\x89\xb2\xe7\x90\x83']
# 宝通寺
# [b'\xe5\xae\x9d\xe9\x80\x9a\xe5\xaf\xba']
# 冲压
# [b'\xe5\x86\xb2\xe5\x8e\x8b']
# 花间
# [b'\xe8\x8a\xb1\xe9\x97\xb4']
# 拉萨
# [b'\xe6\x8b\x89\xe8\x90\xa8']
# 韩国
# [b'\xe9\x9f\xa9\xe5\x9b\xbd']
# 玉米百合
# [b'\xe7\x8e\x89\xe7\xb1\xb3\xe7\x99\xbe\xe5\x90\x88']
# 宋氏家族
# [b'\xe5\xae\x8b\xe6\xb0\x8f\xe5\xae\xb6\xe6\x97\x8f']
# 盘王
# [b'\xe7\x9b\x98\xe7\x8e\x8b']
# 范冰冰
# [b'\xe8\x8c\x83\xe5\x86\xb0\xe5\x86\xb0']
# 中纪委
# [b'\xe4\xb8\xad\xe7\xba\xaa\xe5\xa7\x94']
# 0
# [b'0']
# 宇文成
# [b'\xe5\xae\x87\xe6\x96\x87\xe6\x88\x90']
# 花雕酒
# [b'\xe8\x8a\xb1\xe9\x9b\x95\xe9\x85\x92']
# 兵器谱
# [b'\xe5\x85\xb5\xe5\x99\xa8\xe8\xb0\xb1']
# 南纬
# [b'\xe5\x8d\x97\xe7\xba\xac']
# 英国
# [b'\xe8\x8b\xb1\xe5\x9b\xbd']
# 重庆
# [b'\xe9\x87\x8d\xe5\xba\x86']
# 区号
# [b'\xe5\x8c\xba\xe5\x8f\xb7']
# 66
# [b'66']
# [b'\xe6\x96\xb0\xe5\x8d\x8e\xe5\x8c\xba']
# 期
# [b'\xe6\x9c\x9f']
# 乌兰察布市
# [b'\xe4\xb9\x8c\xe5\x85\xb0\xe5\xaf\x9f\xe5\xb8\x83\xe5\xb8\x82']
# 广岛
# [b'\xe5\xb9\xbf\xe5\xb2\x9b']
# 一叶知秋
# [b'\xe4\xb8\x80\xe5\x8f\xb6\xe7\x9f\xa5\xe7\xa7\x8b']
# 文心雕龙
# [b'\xe6\x96\x87\xe5\xbf\x83\xe9\x9b\x95\xe9\xbe\x99']
# 薛之谦
# [b'\xe8\x96\x9b\xe4\xb9\x8b\xe8\xb0\xa6']
# 杨振宁
# [b'\xe6\x9d\xa8\xe6\x8c\xaf\xe5\xae\x81']
# 林冲
# [b'\xe6\x9e\x97\xe5\x86\xb2']
# 唐汉
# [b'\xe5\x94\x90\xe6\xb1\x89']
# 志
# [b'\xe5\xbf\x97']
# 王丽坤
# [b'\xe7\x8e\x8b\xe4\xb8\xbd\xe5\x9d\xa4']
# 咸宁市
# [b'\xe5\x92\xb8\xe5\xae\x81\xe5\xb8\x82']
# 七星瓢虫
# [b'\xe4\xb8\x83\xe6\x98\x9f\xe7\x93\xa2\xe8\x99\xab']
# 百年孤独
# [b'\xe7\x99\xbe\xe5\xb9\xb4\xe5\xad\xa4\xe7\x8b\xac']
# 闯关东
# [b'\xe9\x97\xaf\xe5\x85\xb3\xe4\xb8\x9c']
# 釜底抽薪
# [b'\xe9\x87\x9c\xe5\xba\x95\xe6\x8a\xbd\xe8\x96\xaa']
# 山西
# [b'\xe5\xb1\xb1\xe8\xa5\xbf']
# 芜湖
# [b'\xe8\x8a\x9c\xe6\xb9\x96']
# 商品房
# [b'\xe5\x95\x86\xe5\x93\x81\xe6\x88\xbf']
# 延川县
# [b'\xe5\xbb\xb6\xe5\xb7\x9d\xe5\x8e\xbf']
# 斗鱼
# [b'\xe6\x96\x97\xe9\xb1\xbc']
# 刘涛王珂
# [b'\xe5\x88\x98\xe6\xb6\x9b\xe7\x8e\x8b\xe7\x8f\x82']
# 绿洲
# [b'\xe7\xbb\xbf\xe6\xb4\xb2']
# 曹操
# [b'\xe6\x9b\xb9\xe6\x93\x8d']
# 以色列
# [b'\xe4\xbb\xa5\xe8\x89\xb2\xe5\x88\x97']
# 辽宁
# [b'\xe8\xbe\xbd\xe5\xae\x81']
# 中国
# [b'\xe4\xb8\xad\xe5\x9b\xbd']
# 诸葛亮
# [b'\xe8\xaf\xb8\xe8\x91\x9b\xe4\xba\xae']
# 埃及
# [b'\xe5\x9f\x83\xe5\x8f\x8a']
# 兴义
# [b'\xe5\x85\xb4\xe4\xb9\x89']
# 金平
# [b'\xe9\x87\x91\xe5\xb9\xb3']
# 白云区
# [b'\xe7\x99\xbd\xe4\xba\x91\xe5\x8c\xba']
# 周长
# [b'\xe5\x91\xa8\xe9\x95\xbf']
# 浙江
# [b'\xe6\xb5\x99\xe6\xb1\x9f']
# 流氓艳遇记
# [b'\xe6\xb5\x81\xe6\xb0\x93\xe8\x89\xb3\xe9\x81\x87\xe8\xae\xb0']
# 中国
# [b'\xe4\xb8\xad\xe5\x9b\xbd']
# 河北省
# [b'\xe6\xb2\xb3\xe5\x8c\x97\xe7\x9c\x81']
# 苍鹰
# [b'\xe8\x8b\x8d\xe9\xb9\xb0']
# 上海
# [b'\xe4\xb8\x8a\xe6\xb5\xb7']
# 头孢
# [b'\xe5\xa4\xb4\xe5\xad\xa2']
# 纸婚
# [b'\xe7\xba\xb8\xe5\xa9\x9a']
# 岫岩
# [b'\xe5\xb2\xab\xe5\xb2\xa9']
# 邢台
# [b'\xe9\x82\xa2\xe5\x8f\xb0']
# 春风十里
# [b'\xe6\x98\xa5\xe9\xa3\x8e\xe5\x8d\x81\xe9\x87\x8c']
# 雍正
# [b'\xe9\x9b\x8d\xe6\xad\xa3']
# 原子弹
# [b'\xe5\x8e\x9f\xe5\xad\x90\xe5\xbc\xb9']
# nter
# [b'nter']
# 广西
# [b'\xe5\xb9\xbf\xe8\xa5\xbf']
# 睾丸
# [b'\xe7\x9d\xbe\xe4\xb8\xb8']
# 林动
# [b'\xe6\x9e\x97\xe5\x8a\xa8']
# 傣族
# [b'\xe5\x82\xa3\xe6\x97\x8f']
# 06年
# [b'06\xe5\xb9\xb4']
# 过电压
# [b'\xe8\xbf\x87\xe7\x94\xb5\xe5\x8e\x8b']
# 年
# [b'\xe5\xb9\xb4']
# 菲律宾
# [b'\xe8\x8f\xb2\xe5\xbe\x8b\xe5\xae\xbe']
# 渡边
# [b'\xe6\xb8\xa1\xe8\xbe\xb9']
# 瓦房店市
# [b'\xe7\x93\xa6\xe6\x88\xbf\xe5\xba\x97\xe5\xb8\x82']
# 白居易
# [b'\xe7\x99\xbd\xe5\xb1\x85\xe6\x98\x93']
# 11月10日
# [b'11\xe6\x9c\x8810\xe6\x97\xa5']
# 田馥甄
# [b'\xe7\x94\xb0\xe9\xa6\xa5\xe7\x94\x84']
# 1024
# [b'1024']
# 半妖倾城
# [b'\xe5\x8d\x8a\xe5\xa6\x96\xe5\x80\xbe\xe5\x9f\x8e']
# 飞机
# [b'\xe9\xa3\x9e\xe6\x9c\xba']
# 西川
# [b'\xe8\xa5\xbf\xe5\xb7\x9d']
# 龙华街道
# [b'\xe9\xbe\x99\xe5\x8d\x8e\xe8\xa1\x97\xe9\x81\x93']
# 月
# [b'\xe6\x9c\x88']
# 南通
# [b'\xe5\x8d\x97\xe9\x80\x9a']
# 800
# [b'800']
# 英国
# [b'\xe8\x8b\xb1\xe5\x9b\xbd']
# 机
# [b'\xe6\x9c\xba']
# 俄罗斯
# [b'\xe4\xbf\x84\xe7\xbd\x97\xe6\x96\xaf']
# 素锦
# [b'\xe7\xb4\xa0\xe9\x94\xa6']
# 清
# [b'\xe6\xb8\x85']
# 大峡谷
# [b'\xe5\xa4\xa7\xe5\xb3\xa1\xe8\xb0\xb7']
# 临安
# [b'\xe4\xb8\xb4\xe5\xae\x89']
# 米
# [b'\xe7\xb1\xb3']
# 李白
# [b'\xe6\x9d\x8e\xe7\x99\xbd']
# [b'\xe9\x99\x87\xe5\x8d\x97\xe5\xb8\x82']
# 猫守鼠洞
# [b'\xe7\x8c\xab\xe5\xae\x88\xe9\xbc\xa0\xe6\xb4\x9e']
# 花生
# [b'\xe8\x8a\xb1\xe7\x94\x9f']
# 四川
# [b'\xe5\x9b\x9b\xe5\xb7\x9d']
# 哈勃
# [b'\xe5\x93\x88\xe5\x8b\x83']
# 唐朝
# [b'\xe5\x94\x90\xe6\x9c\x9d']
# 胰岛素
# [b'\xe8\x83\xb0\xe5\xb2\x9b\xe7\xb4\xa0']
# 陈楚生
# [b'\xe9\x99\x88\xe6\xa5\x9a\xe7\x94\x9f']
# 河北省
# [b'\xe6\xb2\xb3\xe5\x8c\x97\xe7\x9c\x81']
# 苏州
# [b'\xe8\x8b\x8f\xe5\xb7\x9e']
# 桃花开
# [b'\xe6\xa1\x83\xe8\x8a\xb1\xe5\xbc\x80']
# 4
# [b'4']
# 霸王别姬
# [b'\xe9\x9c\xb8\xe7\x8e\x8b\xe5\x88\xab\xe5\xa7\xac']
# 台湾
# [b'\xe5\x8f\xb0\xe6\xb9\xbe']
# 厘米
# [b'\xe5\x8e\x98\xe7\xb1\xb3']
# 41
# [b'41']
# 居里夫人
# [b'\xe5\xb1\x85\xe9\x87\x8c\xe5\xa4\xab\xe4\xba\xba']
# 哈尔滨
# [b'\xe5\x93\x88\xe5\xb0\x94\xe6\xbb\xa8']
# 辽宁省
# [b'\xe8\xbe\xbd\xe5\xae\x81\xe7\x9c\x81']
# 沈星
# [b'\xe6\xb2\x88\xe6\x98\x9f']
# 任达华
# [b'\xe4\xbb\xbb\xe8\xbe\xbe\xe5\x8d\x8e']
# 刘佳
# [b'\xe5\x88\x98\xe4\xbd\xb3']
# 马可波罗
# [b'\xe9\xa9\xac\xe5\x8f\xaf\xe6\xb3\xa2\xe7\xbd\x97']
# iPhone
# [b'iphone']
# 盐城市
# [b'\xe7\x9b\x90\xe5\x9f\x8e\xe5\xb8\x82']
# 韩红
# [b'\xe9\x9f\xa9\xe7\xba\xa2']
# 奶粉
# [b'\xe5\xa5\xb6\xe7\xb2\x89']
# 咸丰
# [b'\xe5\x92\xb8\xe4\xb8\xb0']
# 索菲亚
# [b'\xe7\xb4\xa2\xe8\x8f\xb2\xe4\xba\x9a']
# 瑞典
# [b'\xe7\x91\x9e\xe5\x85\xb8']
# 极品飞车
# [b'\xe6\x9e\x81\xe5\x93\x81\xe9\xa3\x9e\xe8\xbd\xa6']
# 米
# [b'\xe7\xb1\xb3']
# 北回归线
# [b'\xe5\x8c\x97\xe5\x9b\x9e\xe5\xbd\x92\xe7\xba\xbf']
# 乐童
# [b'\xe4\xb9\x90\xe7\xab\xa5']
# 布鲁诺
# [b'\xe5\xb8\x83\xe9\xb2\x81\xe8\xaf\xba']
# 二级
# [b'\xe4\xba\x8c\xe7\xba\xa7']
# 童趣
# [b'\xe7\xab\xa5\xe8\xb6\xa3']
# 1986
# [b'1986']
# 石龙
# [b'\xe7\x9f\xb3\xe9\xbe\x99']
# 云南农业大学
# 胡萝卜
# [b'\xe8\x83\xa1\xe8\x90\x9d\xe5\x8d\x9c']
# 红米
# [b'\xe7\xba\xa2\xe7\xb1\xb3']
# 牛郎织女
# [b'\xe7\x89\x9b\xe9\x83\x8e\xe7\xbb\x87\xe5\xa5\xb3']
# 云南
# [b'\xe4\xba\x91\xe5\x8d\x97']
# 宝骏
# [b'\xe5\xae\x9d\xe9\xaa\x8f']
# 海湾战争
# [b'\xe6\xb5\xb7\xe6\xb9\xbe\xe6\x88\x98\xe4\xba\x89']
# 专利
# [b'\xe4\xb8\x93\xe5\x88\xa9']
# 张庭瑚
# [b'\xe5\xbc\xa0\xe5\xba\xad\xe7\x91\x9a']
# 大连
# [b'\xe5\xa4\xa7\xe8\xbf\x9e']
# Gee
# [b'gee']
# 奇怪
# [b'\xe5\xa5\x87\xe6\x80\xaa']
# 夏东海
# [b'\xe5\xa4\x8f\xe4\xb8\x9c\xe6\xb5\xb7']
# 河南省
# [b'\xe6\xb2\xb3\xe5\x8d\x97\xe7\x9c\x81']
# 荆门
# [b'\xe8\x8d\x86\xe9\x97\xa8']
# 秦朝
# [b'\xe7\xa7\xa6\xe6\x9c\x9d']
# 巴厘岛
# [b'\xe5\xb7\xb4\xe5\x8e\x98\xe5\xb2\x9b']
# 脑白金
# [b'\xe8\x84\x91\xe7\x99\xbd\xe9\x87\x91']
# 100
# [b'100']
# 曾轶可
# [b'\xe6\x9b\xbe\xe8\xbd\xb6\xe5\x8f\xaf']
# 薛之谦
# [b'\xe8\x96\x9b\xe4\xb9\x8b\xe8\xb0\xa6']
# 核磁共振
# [b'\xe6\xa0\xb8\xe7\xa3\x81\xe5\x85\xb1\xe6\x8c\xaf']
# 2
# [b'2']
# 天津
# [b'\xe5\xa4\xa9\xe6\xb4\xa5']
# 己卯
# [b'\xe5\xb7\xb1\xe5\x8d\xaf']
# 隋朝
# [b'\xe9\x9a\x8b\xe6\x9c\x9d']
# 安徽
# [b'\xe5\xae\x89\xe5\xbe\xbd']
# 新生化
# [b'\xe6\x96\xb0\xe7\x94\x9f\xe5\x8c\x96']
# 双色球
# [b'\xe5\x8f\x8c\xe8\x89\xb2\xe7\x90\x83']
# 大理石
# [b'\xe5\xa4\xa7\xe7\x90\x86\xe7\x9f\xb3']
# 七月
# [b'\xe4\xb8\x83\xe6\x9c\x88']
# 莒南
# [b'\xe8\x8e\x92\xe5\x8d\x97']
# 北京
# [b'\xe5\x8c\x97\xe4\xba\xac']
# 潘罗森
# [b'\xe6\xbd\x98\xe7\xbd\x97\xe6\xa3\xae']
# 微米
# [b'\xe5\xbe\xae\xe7\xb1\xb3']
# 消防安全
# [b'\xe6\xb6\x88\xe9\x98\xb2\xe5\xae\x89\xe5\x85\xa8']
# 海南医学院
# [b'\xe6\xb5\xb7\xe5\x8d\x97\xe5\x8c\xbb\xe5\xad\xa6\xe9\x99\xa2']
# 刘嘉玲
# [b'\xe5\x88\x98\xe5\x98\x89\xe7\x8e\xb2']
# 牡丹江市
# [b'\xe7\x89\xa1\xe4\xb8\xb9\xe6\xb1\x9f\xe5\xb8\x82']
# 拉合尔
# [b'\xe6\x8b\x89\xe5\x90\x88\xe5\xb0\x94']
# 宝
# [b'\xe5\xae\x9d']
# 基督教
# [b'\xe5\x9f\xba\xe7\x9d\xa3\xe6\x95\x99']
# 陈赫
# [b'\xe9\x99\x88\xe8\xb5\xab']
# 吴用
# [b'\xe5\x90\xb4\xe7\x94\xa8']
# 刘亦菲
# [b'\xe5\x88\x98\xe4\xba\xa6\xe8\x8f\xb2']
# 四川省
# [b'\xe5\x9b\x9b\xe5\xb7\x9d\xe7\x9c\x81']
# 澳大利亚
# [b'\xe6\xbe\xb3\xe5\xa4\xa7\xe5\x88\xa9\xe4\xba\x9a']
# 四川
# [b'\xe5\x9b\x9b\xe5\xb7\x9d']
# 保加利亚
# [b'\xe4\xbf\x9d\xe5\x8a\xa0\xe5\x88\xa9\xe4\xba\x9a']
# 电池
# [b'\xe7\x94\xb5\xe6\xb1\xa0']
# 柏拉图
# [b'\xe6\x9f\x8f\xe6\x8b\x89\xe5\x9b\xbe']
# 麦长青
# [b'\xe9\xba\xa6\xe9\x95\xbf\xe9\x9d\x92']
# 160
# [b'160']
# 闵行区
# [b'\xe9\x97\xb5\xe8\xa1\x8c\xe5\x8c\xba']
# 下士
# [b'\xe4\xb8\x8b\xe5\xa3\xab']
# 凤冈
# [b'\xe5\x87\xa4\xe5\x86\x88']
# 摩拜
# [b'\xe6\x91\xa9\xe6\x8b\x9c']
# 哮天犬
# [b'\xe5\x93\xae\xe5\xa4\xa9\xe7\x8a\xac']
# 木
# [b'\xe6\x9c\xa8']
# 咸水湖
# [b'\xe5\x92\xb8\xe6\xb0\xb4\xe6\xb9\x96']
# 2
# [b'2']
# 赵丽颖
# [b'\xe8\xb5\xb5\xe4\xb8\xbd\xe9\xa2\x96']
# 杜甫
# [b'\xe6\x9d\x9c\xe7\x94\xab']
# 金华
# [b'\xe9\x87\x91\xe5\x8d\x8e']
# 征信
# [b'\xe5\xbe\x81\xe4\xbf\xa1']
# 奈
# [b'\xe5\xa5\x88']
# 瓦房店
# [b'\xe7\x93\xa6\xe6\x88\xbf\xe5\xba\x97']
# 赵文卓
# [b'\xe8\xb5\xb5\xe6\x96\x87\xe5\x8d\x93']
# 千岛
# [b'\xe5\x8d\x83\xe5\xb2\x9b']
# 习近平
# [b'\xe4\xb9\xa0\xe8\xbf\x91\xe5\xb9\xb3']
# 齐齐哈尔市
# [b'\xe9\xbd\x90\xe9\xbd\x90\xe5\x93\x88\xe5\xb0\x94\xe5\xb8\x82']
# 俄国
# [b'\xe4\xbf\x84\xe5\x9b\xbd']
# 所罗门
# [b'\xe6\x89\x80\xe7\xbd\x97\xe9\x97\xa8']
# 美国
# [b'\xe7\xbe\x8e\xe5\x9b\xbd']
# 鲁迅
# [b'\xe9\xb2\x81\xe8\xbf\x85']
# 柬埔寨
# [b'\xe6\x9f\xac\xe5\x9f\x94\xe5\xaf\xa8']
# 刘德华
# [b'\xe5\x88\x98\xe5\xbe\xb7\xe5\x8d\x8e']
# [b'\xe4\xba\xba\xe6\x89\x8d\xe6\xb5\x8e\xe6\xb5\x8e']
# 牧马人
# [b'\xe7\x89\xa7\xe9\xa9\xac\xe4\xba\xba']
# 广州
# [b'\xe5\xb9\xbf\xe5\xb7\x9e']
# 2
# [b'2']
# 黑色
# [b'\xe9\xbb\x91\xe8\x89\xb2']
# 红色或蓝色
# [b'\xe7\xba\xa2\xe8\x89\xb2\xe6\x88\x96\xe8\x93\x9d\xe8\x89\xb2']
# 吉首市
# [b'\xe5\x90\x89\xe9\xa6\x96\xe5\xb8\x82']
# 2天
# [b'2\xe5\xa4\xa9']
# 2
# [b'2']
# 10月1日
# [b'10\xe6\x9c\x881\xe6\x97\xa5']
# 2部
# [b'2\xe9\x83\xa8']
# 20星
# [b'20\xe6\x98\x9f']
# 三
# [b'\xe4\xb8\x89']
# 39周
# [b'39\xe5\x91\xa8']
# 阜阳市
# [b'\xe9\x98\x9c\xe9\x98\xb3\xe5\xb8\x82']
# 扇形
# [b'\xe6\x89\x87\xe5\xbd\xa2']
# 600块
# [b'600\xe5\x9d\x97']
# 有口皆碑
# [b'\xe6\x9c\x89\xe5\x8f\xa3\xe7\x9a\x86\xe7\xa2\x91']
# 35码
# [b'35\xe7\xa0\x81']
# 新疆
# [b'\xe6\x96\xb0\xe7\x96\x86']
# 90平方米
# [b'90\xe5\xb9\xb3\xe6\x96\xb9\xe7\xb1\xb3']
# 美团网
# [b'\xe7\xbe\x8e\xe5\x9b\xa2\xe7\xbd\x91']
# 泰拳
# [b'\xe6\xb3\xb0\xe6\x8b\xb3']
# 80年2
# [b'80\xe5\xb9\xb42']
# 英国
# [b'\xe8\x8b\xb1\xe5\x9b\xbd']
# 罗汉果
# [b'\xe7\xbd\x97\xe6\xb1\x89\xe6\x9e\x9c']
# 南宁地区
# [b'\xe5\x8d\x97\xe5\xae\x81\xe5\x9c\xb0\xe5\x8c\xba']
# 怀特
# [b'\xe6\x80\x80\xe7\x89\xb9']
# 海林市
# [b'\xe6\xb5\xb7\xe6\x9e\x97\xe5\xb8\x82']
# 崇文区
# [b'\xe5\xb4\x87\xe6\x96\x87\xe5\x8c\xba']
# 声波
# [b'\xe5\xa3\xb0\xe6\xb3\xa2']
# 800
# [b'800']
# 十三个
# [b'\xe5\x8d\x81\xe4\xb8\x89\xe4\xb8\xaa']
# 天界
# [b'\xe5\xa4\xa9\xe7\x95\x8c']
# 牛根生
# [b'\xe7\x89\x9b\xe6\xa0\xb9\xe7\x94\x9f']
# 第47集
# [b'\xe7\xac\xac47\xe9\x9b\x86']
# 莫停
# [b'\xe8\x8e\xab\xe5\x81\x9c']
# 元始天尊
# [b'\xe5\x85\x83\xe5\xa7\x8b\xe5\xa4\xa9\xe5\xb0\x8a']
# 极速绯闻
# [b'\xe6\x9e\x81\xe9\x80\x9f\xe7\xbb\xaf\xe9\x97\xbb']
# 公元前316年
# [b'\xe5\x85\xac\xe5\x85\x83\xe5\x89\x8d316\xe5\xb9\xb4']
# 乾隆
# [b'\xe4\xb9\xbe\xe9\x9a\x86']
# 小幸运
# [b'\xe5\xb0\x8f\xe5\xb9\xb8\xe8\xbf\x90']
# 人民代表大会
# [b'\xe4\xba\xba\xe6\xb0\x91\xe4\xbb\xa3\xe8\xa1\xa8\xe5\xa4\xa7\xe4\xbc\x9a']
# 万位
# [b'\xe4\xb8\x87\xe4\xbd\x8d']
# 菊花
# [b'\xe8\x8f\x8a\xe8\x8a\xb1']
# 直角
# [b'\xe7\x9b\xb4\xe8\xa7\x92']
# 老虎
# [b'\xe8\x80\x81\xe8\x99\x8e']
# 1米
# [b'1\xe7\xb1\xb3']
# 我愿意
# [b'\xe6\x88\x91\xe6\x84\xbf\xe6\x84\x8f']
# 巧克力
# [b'\xe5\xb7\xa7\xe5\x85\x8b\xe5\x8a\x9b']
# 党内选举
# [b'\xe5\x85\x9a\xe5\x86\x85\xe9\x80\x89\xe4\xb8\xbe']
# 亥时
# [b'\xe4\xba\xa5\xe6\x97\xb6']
# 70
# [b'70']
# 乔玄
# [b'\xe4\xb9\x94\xe7\x8e\x84']
# 英国
# [b'\xe8\x8b\xb1\xe5\x9b\xbd']
# 思茅地区
# [b'\xe6\x80\x9d\xe8\x8c\x85\xe5\x9c\xb0\xe5\x8c\xba']
# 禁军
# [b'\xe7\xa6\x81\xe5\x86\x9b']
# 1个
# [b'1\xe4\xb8\xaa']
# 李佳
# [b'\xe6\x9d\x8e\xe4\xbd\xb3']
# 310
# [b'310']
# 俄语
# [b'\xe4\xbf\x84\xe8\xaf\xad']
# 25天
# [b'25\xe5\xa4\xa9']
# 收买人心
# [b'\xe6\x94\xb6\xe4\xb9\xb0\xe4\xba\xba\xe5\xbf\x83']
# 落雨辰
# [b'\xe8\x90\xbd\xe9\x9b\xa8\xe8\xbe\xb0']
# 英国
# [b'\xe8\x8b\xb1\xe5\x9b\xbd']
# 2.4尺,也就是2尺4寸
# [b'2', b'4\xe5\xb0\xba', b'\xe4\xb9\x9f\xe5\xb0\xb1\xe6\x98\xaf2\xe5\xb0\xba4\xe5\xaf\xb8']
# 蓝钻
# [b'\xe8\x93\x9d\xe9\x92\xbb']
# 8月4日
# [b'8\xe6\x9c\x884\xe6\x97\xa5']
# 26集
# [b'26\xe9\x9b\x86']
# 2
# [b'2']
# 开尔文
# [b'\xe5\xbc\x80\xe5\xb0\x94\xe6\x96\x87']
# 丁波
# [b'\xe4\xb8\x81\xe6\xb3\xa2']
# 周朝
# [b'\xe5\x91\xa8\xe6\x9c\x9d']
# 发动机
# [b'\xe5\x8f\x91\xe5\x8a\xa8\xe6\x9c\xba']
# 2003年
# [b'2003\xe5\xb9\xb4']
# 40人
# [b'40\xe4\xba\xba']
# 100
# [b'100']
# 三个
# [b'\xe4\xb8\x89\xe4\xb8\xaa']
# 遵义会议
# [b'\xe9\x81\xb5\xe4\xb9\x89\xe4\xbc\x9a\xe8\xae\xae']
# 2885平方公里
# [b'2885\xe5\xb9\xb3\xe6\x96\xb9\xe5\x85\xac\xe9\x87\x8c']
# 730万公里
# [b'730\xe4\xb8\x87\xe5\x85\xac\xe9\x87\x8c']
# 手镯
# [b'\xe6\x89\x8b\xe9\x95\xaf']
# 1931年
# [b'1931\xe5\xb9\xb4']
# 伯
# [b'\xe4\xbc\xaf']
# 福特
# [b'\xe7\xa6\x8f\xe7\x89\xb9']
# 2
# [b'2']
# 仰融
# [b'\xe4\xbb\xb0\xe8\x9e\x8d']
# 徐本禹
# [b'\xe5\xbe\x90\xe6\x9c\xac\xe7\xa6\xb9']
# 内蒙古自治区
# [b'\xe5\x86\x85\xe8\x92\x99\xe5\x8f\xa4\xe8\x87\xaa\xe6\xb2\xbb\xe5\x8c\xba']
# 海淀区
# [b'\xe6\xb5\xb7\xe6\xb7\x80\xe5\x8c\xba']
# 15分钟
# [b'15\xe5\x88\x86\xe9\x92\x9f']
# 山东省
# [b'\xe5\xb1\xb1\xe4\xb8\x9c\xe7\x9c\x81']
# 180度
# [b'180\xe5\xba\xa6']
# 翁美玲
# [b'\xe7\xbf\x81\xe7\xbe\x8e\xe7\x8e\xb2']
# 琵琶行
# [b'\xe7\x90\xb5\xe7\x90\xb6\xe8\xa1\x8c']
# 刘仲元
# [b'\xe5\x88\x98\xe4\xbb\xb2\xe5\x85\x83']
# 钟欣潼
# [b'\xe9\x92\x9f\xe6\xac\xa3\xe6\xbd\xbc']
# 第516集
# [b'\xe7\xac\xac516\xe9\x9b\x86']
# 水蒸气
# [b'\xe6\xb0\xb4\xe8\x92\xb8\xe6\xb0\x94']
# 印度尼西亚
# [b'\xe5\x8d\xb0\xe5\xba\xa6\xe5\xb0\xbc\xe8\xa5\xbf\xe4\xba\x9a']
# 2
# [b'2']
# 黄志忠
# [b'\xe9\xbb\x84\xe5\xbf\x97\xe5\xbf\xa0']
# 汕头市
# [b'\xe6\xb1\x95\xe5\xa4\xb4\xe5\xb8\x82']
# 唐朝
# [b'\xe5\x94\x90\xe6\x9c\x9d']
# 棕榈科
# [b'\xe6\xa3\x95\xe6\xa6\x88\xe7\xa7\x91']
# 李孝利
# [b'\xe6\x9d\x8e\xe5\xad\x9d\xe5\x88\xa9']
# 莫斯科
# [b'\xe8\x8e\xab\xe6\x96\xaf\xe7\xa7\x91']
# 第九集
# [b'\xe7\xac\xac\xe4\xb9\x9d\xe9\x9b\x86']
# RNG
# [b'rng']
# 5分钟
# [b'5\xe5\x88\x86\xe9\x92\x9f']
# 140米
# [b'140\xe7\xb1\xb3']
# 红烧肉
# [b'\xe7\xba\xa2\xe7\x83\xa7\xe8\x82\x89']
# 金冠
# [b'\xe9\x87\x91\xe5\x86\xa0']
# 十年少
# [b'\xe5\x8d\x81\xe5\xb9\xb4\xe5\xb0\x91']
# 意大利
# [b'\xe6\x84\x8f\xe5\xa4\xa7\xe5\x88\xa9']
# 刘三姐
# [b'\xe5\x88\x98\xe4\xb8\x89\xe5\xa7\x90']
# 三次
# [b'\xe4\xb8\x89\xe6\xac\xa1']
# 张丹峰
# [b'\xe5\xbc\xa0\xe4\xb8\xb9\xe5\xb3\xb0']
# 苏州市吴江区
# [b'\xe8\x8b\x8f\xe5\xb7\x9e\xe5\xb8\x82\xe5\x90\xb4\xe6\xb1\x9f\xe5\x8c\xba']
# 鲁迅
# [b'\xe9\xb2\x81\xe8\xbf\x85']
# 熊梓淇
# [b'\xe7\x86\x8a\xe6\xa2\x93\xe6\xb7\x87']
# 贾静雯
# [b'\xe8\xb4\xbe\xe9\x9d\x99\xe9\x9b\xaf']
# 浏览器
# [b'\xe6\xb5\x8f\xe8\xa7\x88\xe5\x99\xa8']
# 西晋
# [b'\xe8\xa5\xbf\xe6\x99\x8b']
# 冬
# [b'\xe5\x86\xac']
# 桃城区
# [b'\xe6\xa1\x83\xe5\x9f\x8e\xe5\x8c\xba']
# 朱序
# [b'\xe6\x9c\xb1\xe5\xba\x8f']
# 2
# [b'2']
# 三峡大学
# [b'\xe4\xb8\x89\xe5\xb3\xa1\xe5\xa4\xa7\xe5\xad\xa6']
# 7月11日
# [b'7\xe6\x9c\x8811\xe6\x97\xa5']
# 紫菜
# [b'\xe7\xb4\xab\xe8\x8f\x9c']
# 10月18日
# [b'10\xe6\x9c\x8818\xe6\x97\xa5']
# 上海
# [b'\xe4\xb8\x8a\xe6\xb5\xb7']
# 雅各布斯
# [b'\xe9\x9b\x85\xe5\x90\x84\xe5\xb8\x83\xe6\x96\xaf']
# 美国
# [b'\xe7\xbe\x8e\xe5\x9b\xbd']
# 张杰
# [b'\xe5\xbc\xa0\xe6\x9d\xb0']
# 京东
# [b'\xe4\xba\xac\xe4\xb8\x9c']
# 孙悦
# [b'\xe5\xad\x99\xe6\x82\xa6']
# 吴胜利
# [b'\xe5\x90\xb4\xe8\x83\x9c\xe5\x88\xa9']
# 三原色
# [b'\xe4\xb8\x89\xe5\x8e\x9f\xe8\x89\xb2']
# 二套
# [b'\xe4\xba\x8c\xe5\xa5\x97']
# 3种
# [b'3\xe7\xa7\x8d']
# 日立
# [b'\xe6\x97\xa5\xe7\xab\x8b']
# 慕容博
# [b'\xe6\x85\x95\xe5\xae\xb9\xe5\x8d\x9a']
# 岷江
# [b'\xe5\xb2\xb7\xe6\xb1\x9f']
# 视在功率
# [b'\xe8\xa7\x86\xe5\x9c\xa8\xe5\x8a\x9f\xe7\x8e\x87']
# 维吾尔族
# [b'\xe7\xbb\xb4\xe5\x90\xbe\xe5\xb0\x94\xe6\x97\x8f']
# 嘉定区
# [b'\xe5\x98\x89\xe5\xae\x9a\xe5\x8c\xba']
# 两千平方米
# [b'\xe4\xb8\xa4\xe5\x8d\x83\xe5\xb9\xb3\xe6\x96\xb9\xe7\xb1\xb3']
# 邪魅公子
# [b'\xe9\x82\xaa\xe9\xad\x85\xe5\x85\xac\xe5\xad\x90']
# 西游记
# [b'\xe8\xa5\xbf\xe6\xb8\xb8\xe8\xae\xb0']
# 广州塔
# [b'\xe5\xb9\xbf\xe5\xb7\x9e\xe5\xa1\x94']
# 十二级
# [b'\xe5\x8d\x81\xe4\xba\x8c\xe7\xba\xa7']
# 天鹅
# [b'\xe5\xa4\xa9\xe9\xb9\x85']
# 报倾城随太守
# [b'\xe6\x8a\xa5\xe5\x80\xbe\xe5\x9f\x8e\xe9\x9a\x8f\xe5\xa4\xaa\xe5\xae\x88']
# 三年
# [b'\xe4\xb8\x89\xe5\xb9\xb4']
# 7月1日
# [b'7\xe6\x9c\x881\xe6\x97\xa5']
# 宋代
# [b'\xe5\xae\x8b\xe4\xbb\xa3']
# 孙俪
# [b'\xe5\xad\x99\xe4\xbf\xaa']
# 李忆如
# [b'\xe6\x9d\x8e\xe5\xbf\x86\xe5\xa6\x82']
# 那一天
# [b'\xe9\x82\xa3\xe4\xb8\x80\xe5\xa4\xa9']
# 死海
# [b'\xe6\xad\xbb\xe6\xb5\xb7']
# 好高骛远
# [b'\xe5\xa5\xbd\xe9\xab\x98\xe9\xaa\x9b\xe8\xbf\x9c']
# 黄山市
# [b'\xe9\xbb\x84\xe5\xb1\xb1\xe5\xb8\x82']
# 公安局
# [b'\xe5\x85\xac\xe5\xae\x89\xe5\xb1\x80']
# 15度
# [b'15\xe5\xba\xa6']
# 崇左市
# [b'\xe5\xb4\x87\xe5\xb7\xa6\xe5\xb8\x82']
# 普希金
# [b'\xe6\x99\xae\xe5\xb8\x8c\xe9\x87\x91']
# 李璇玑
# [b'\xe6\x9d\x8e\xe7\x92\x87\xe7\x8e\x91']
# 柳河东
# [b'\xe6\x9f\xb3\xe6\xb2\xb3\xe4\xb8\x9c']
# 2寸
# [b'2\xe5\xaf\xb8']
# 4号
# [b'4\xe5\x8f\xb7']
# 六位
# [b'\xe5\x85\xad\xe4\xbd\x8d']
# 东半球
# [b'\xe4\xb8\x9c\xe5\x8d\x8a\xe7\x90\x83']
# 10分钟
# [b'10\xe5\x88\x86\xe9\x92\x9f']
# 100
# [b'100']
# 吉田
# [b'\xe5\x90\x89\xe7\x94\xb0']
# ofo
# [b'ofo']
# 60000
# [b'60000']
# 五四运动
# [b'\xe4\xba\x94\xe5\x9b\x9b\xe8\xbf\x90\xe5\x8a\xa8']
# 两寸
# [b'\xe4\xb8\xa4\xe5\xaf\xb8']
# 3.7伏
# [b'3', b'7\xe4\xbc\x8f']
# 字节
# [b'\xe5\xad\x97\xe8\x8a\x82']
# 四夜奇谭
# [b'\xe5\x9b\x9b\xe5\xa4\x9c\xe5\xa5\x87\xe8\xb0\xad']
# 2
# [b'2']
# 7天
# [b'7\xe5\xa4\xa9']
# 轮胎
# [b'\xe8\xbd\xae\xe8\x83\x8e']
# 圆球体
# [b'\xe5\x9c\x86\xe7\x90\x83\xe4\xbd\x93']
# 艾克斯
# [b'\xe8\x89\xbe\xe5\x85\x8b\xe6\x96\xaf']
# 阿信
# [b'\xe9\x98\xbf\xe4\xbf\xa1']
# 第64集
# [b'\xe7\xac\xac64\xe9\x9b\x86']
# 陈亚洲
# [b'\xe9\x99\x88\xe4\xba\x9a\xe6\xb4\xb2']
# 5月11日
# [b'5\xe6\x9c\x8811\xe6\x97\xa5']
# 张杰
# [b'\xe5\xbc\xa0\xe6\x9d\xb0']
# 27000
# [b'27000']
# 陈奕迅
# [b'\xe9\x99\x88\xe5\xa5\x95\xe8\xbf\x85']
# 春菜
# [b'\xe6\x98\xa5\xe8\x8f\x9c']
# 黄麻起义
# [b'\xe9\xbb\x84\xe9\xba\xbb\xe8\xb5\xb7\xe4\xb9\x89']
# 鄱阳湖
# [b'\xe9\x84\xb1\xe9\x98\xb3\xe6\xb9\x96']
# 薛之谦
# [b'\xe8\x96\x9b\xe4\xb9\x8b\xe8\xb0\xa6']
# 二年
# [b'\xe4\xba\x8c\xe5\xb9\xb4']
# 岳麓区
# [b'\xe5\xb2\xb3\xe9\xba\x93\xe5\x8c\xba']
# 吴昕
# [b'\xe5\x90\xb4\xe6\x98\x95']
# 15日
# [b'15\xe6\x97\xa5']
# 赵山河
# [b'\xe8\xb5\xb5\xe5\xb1\xb1\xe6\xb2\xb3']
# 9位
# [b'9\xe4\xbd\x8d']
# 第11集
# [b'\xe7\xac\xac11\xe9\x9b\x86']
# 16画
# [b'16\xe7\x94\xbb']
# 黑龙滩
# [b'\xe9\xbb\x91\xe9\xbe\x99\xe6\xbb\xa9']
# 五洲
# [b'\xe4\xba\x94\xe6\xb4\xb2']
# 鸡西市
# [b'\xe9\xb8\xa1\xe8\xa5\xbf\xe5\xb8\x82']
# 谭晶
# [b'\xe8\xb0\xad\xe6\x99\xb6']
# 白色
# [b'\xe7\x99\xbd\xe8\x89\xb2']
# 南极洲
# [b'\xe5\x8d\x97\xe6\x9e\x81\xe6\xb4\xb2']
# 洋务派
# [b'\xe6\xb4\x8b\xe5\x8a\xa1\xe6\xb4\xbe']
# 桂林市
# [b'\xe6\xa1\x82\xe6\x9e\x97\xe5\xb8\x82']
# 三叶草
# [b'\xe4\xb8\x89\xe5\x8f\xb6\xe8\x8d\x89']
# 三个
# [b'\xe4\xb8\x89\xe4\xb8\xaa']
# 高桥美香
# [b'\xe9\xab\x98\xe6\xa1\xa5\xe7\xbe\x8e\xe9\xa6\x99']
# 定音鼓
# [b'\xe5\xae\x9a\xe9\x9f\xb3\xe9\xbc\x93']
# 野火烧不尽
# [b'\xe9\x87\x8e\xe7\x81\xab\xe7\x83\xa7\xe4\xb8\x8d\xe5\xb0\xbd']
# 5464公里
# [b'5464\xe5\x85\xac\xe9\x87\x8c']
# 合肥市
# [b'\xe5\x90\x88\xe8\x82\xa5\xe5\xb8\x82']
# 40集
# [b'40\xe9\x9b\x86']
# 四声
# [b'\xe5\x9b\x9b\xe5\xa3\xb0']
# 雪茄
# [b'\xe9\x9b\xaa\xe8\x8c\x84']
# 王汉青
# [b'\xe7\x8e\x8b\xe6\xb1\x89\xe9\x9d\x92']
# 崇安区
# [b'\xe5\xb4\x87\xe5\xae\x89\xe5\x8c\xba']
# 4个
# [b'4\xe4\xb8\xaa']
# 4
# [b'4']
# 4层
# [b'4\xe5\xb1\x82']
# 孙殿英
# [b'\xe5\xad\x99\xe6\xae\xbf\xe8\x8b\xb1']
# 大禹治水
# [b'\xe5\xa4\xa7\xe7\xa6\xb9\xe6\xb2\xbb\xe6\xb0\xb4']
# 万科
# [b'\xe4\xb8\x87\xe7\xa7\x91']
# 萧景禹
# [b'\xe8\x90\xa7\xe6\x99\xaf\xe7\xa6\xb9']
# 形变
# [b'\xe5\xbd\xa2\xe5\x8f\x98']
# 火腿肠
# [b'\xe7\x81\xab\xe8\x85\xbf\xe8\x82\xa0']
# 11月3日
# [b'11\xe6\x9c\x883\xe6\x97\xa5']
# 第2滴血
# [b'\xe7\xac\xac2\xe6\xbb\xb4\xe8\xa1\x80']
# 狮子座
# [b'\xe7\x8b\xae\xe5\xad\x90\xe5\xba\xa7']
# 四叶草
# [b'\xe5\x9b\x9b\xe5\x8f\xb6\xe8\x8d\x89']
# 2
# [b'2']
# 浪淘沙
# [b'\xe6\xb5\xaa\xe6\xb7\x98\xe6\xb2\x99']
# 紫色
# [b'\xe7\xb4\xab\xe8\x89\xb2']
# 2
# [b'2']
# 2
# [b'2']
# 毛
# [b'\xe6\xaf\x9b']
# 河北省
# [b'\xe6\xb2\xb3\xe5\x8c\x97\xe7\x9c\x81']
# 三线
# [b'\xe4\xb8\x89\xe7\xba\xbf']
# 三本
# [b'\xe4\xb8\x89\xe6\x9c\xac']
# 2017年
# [b'2017\xe5\xb9\xb4']
# 杨子荣
# [b'\xe6\x9d\xa8\xe5\xad\x90\xe8\x8d\xa3']
# 张良
# [b'\xe5\xbc\xa0\xe8\x89\xaf']
# 郑关西
# [b'\xe9\x83\x91\xe5\x85\xb3\xe8\xa5\xbf']
# 英是
# [b'\xe8\x8b\xb1\xe6\x98\xaf']
# 100
# [b'100']
# 黄岩岛
# [b'\xe9\xbb\x84\xe5\xb2\xa9\xe5\xb2\x9b']
# 皇冠
# [b'\xe7\x9a\x87\xe5\x86\xa0']
# yù
# [b'y\xc3\xb9']
# 慕言
# [b'\xe6\x85\x95\xe8\xa8\x80']
# 南宋
# [b'\xe5\x8d\x97\xe5\xae\x8b']
# 口才实战
# [b'\xe5\x8f\xa3\xe6\x89\x8d\xe5\xae\x9e\xe6\x88\x98']
# 0515期
# [b'0515\xe6\x9c\x9f']
# 香港风尚国际、内地华谊
# [b'\xe9\xa6\x99\xe6\xb8\xaf\xe9\xa3\x8e\xe5\xb0\x9a\xe5\x9b\xbd\xe9\x99\x85', b'\xe5\x86\x85\xe5\x9c\xb0\xe5\x8d\x8e\xe8\xb0\x8a']
# 关羽
# [b'\xe5\x85\xb3\xe7\xbe\xbd']
# 45
# [b'45']
# 山东省济宁市
# [b'\xe5\xb1\xb1\xe4\xb8\x9c\xe7\x9c\x81\xe6\xb5\x8e\xe5\xae\x81\xe5\xb8\x82']
# 锦江区
# [b'\xe9\x94\xa6\xe6\xb1\x9f\xe5\x8c\xba']
# 股东会
# [b'\xe8\x82\xa1\xe4\xb8\x9c\xe4\xbc\x9a']
# 100克
# [b'100\xe5\x85\x8b']
# 伏羲
# [b'\xe4\xbc\x8f\xe7\xbe\xb2']
# 张亮
# [b'\xe5\xbc\xa0\xe4\xba\xae']
# 100
# [b'100']
# 二十四小时
# [b'\xe4\xba\x8c\xe5\x8d\x81\xe5\x9b\x9b\xe5\xb0\x8f\xe6\x97\xb6']
# 77部
# [b'77\xe9\x83\xa8']
# yì
# [b'y\xc3\xac']
# 邓超
# [b'\xe9\x82\x93\xe8\xb6\x85']
# 四声
# [b'\xe5\x9b\x9b\xe5\xa3\xb0']
# 61集
# [b'61\xe9\x9b\x86']
# 姚中仁
# [b'\xe5\xa7\x9a\xe4\xb8\xad\xe4\xbb\x81']
# 文梦洋
# [b'\xe6\x96\x87\xe6\xa2\xa6\xe6\xb4\x8b']
# 24个
# [b'24\xe4\xb8\xaa']
# 鲸鱼
# [b'\xe9\xb2\xb8\xe9\xb1\xbc']
# 平方公顷
# [b'\xe5\xb9\xb3\xe6\x96\xb9\xe5\x85\xac\xe9\xa1\xb7']
# 宿迁
# [b'\xe5\xae\xbf\xe8\xbf\x81']
# 14天
# [b'14\xe5\xa4\xa9']
# 柳岩
# [b'\xe6\x9f\xb3\xe5\xb2\xa9']
# 四月十九日
# [b'\xe5\x9b\x9b\xe6\x9c\x88\xe5\x8d\x81\xe4\xb9\x9d\xe6\x97\xa5']
# 1991年
# [b'1991\xe5\xb9\xb4']
# 伽利略
# [b'\xe4\xbc\xbd\xe5\x88\xa9\xe7\x95\xa5']
# 巨蟹座
# [b'\xe5\xb7\xa8\xe8\x9f\xb9\xe5\xba\xa7']
# 陈燮霞
# [b'\xe9\x99\x88\xe7\x87\xae\xe9\x9c\x9e']
# 19集
# [b'19\xe9\x9b\x86']
# 安装盘
# [b'\xe5\xae\x89\xe8\xa3\x85\xe7\x9b\x98']
# 元灵
# [b'\xe5\x85\x83\xe7\x81\xb5']
# 广西自治区
# [b'\xe5\xb9\xbf\xe8\xa5\xbf\xe8\x87\xaa\xe6\xb2\xbb\xe5\x8c\xba']
# 世间情为何物,一物降一物
# [b'\xe4\xb8\x96\xe9\x97\xb4\xe6\x83\x85\xe4\xb8\xba\xe4\xbd\x95\xe7\x89\xa9', b'\xe4\xb8\x80\xe7\x89\xa9\xe9\x99\x8d\xe4\xb8\x80\xe7\x89\xa9']
# 二个
# [b'\xe4\xba\x8c\xe4\xb8\xaa']
# 牵引车
# [b'\xe7\x89\xb5\xe5\xbc\x95\xe8\xbd\xa6']
# xīn
# [b'x\xc4\xabn']
# 狄仁杰
# [b'\xe7\x8b\x84\xe4\xbb\x81\xe6\x9d\xb0']
# 水水山山
# [b'\xe6\xb0\xb4\xe6\xb0\xb4\xe5\xb1\xb1\xe5\xb1\xb1']
# 黄诗佳
# [b'\xe9\xbb\x84\xe8\xaf\x97\xe4\xbd\xb3']
# 渔家傲
# [b'\xe6\xb8\x94\xe5\xae\xb6\xe5\x82\xb2']
# 220伏
# [b'220\xe4\xbc\x8f']
# 马克思主义
# [b'\xe9\xa9\xac\xe5\x85\x8b\xe6\x80\x9d\xe4\xb8\xbb\xe4\xb9\x89']
# 法国
# [b'\xe6\xb3\x95\xe5\x9b\xbd']
# 洞庭湖
# [b'\xe6\xb4\x9e\xe5\xba\xad\xe6\xb9\x96']
# 许明明
# [b'\xe8\xae\xb8\xe6\x98\x8e\xe6\x98\x8e']
# sell
# [b'sell']
# 李宗盛
# [b'\xe6\x9d\x8e\xe5\xae\x97\xe7\x9b\x9b']
# 18
# [b'18']
# 刘亦菲
# [b'\xe5\x88\x98\xe4\xba\xa6\xe8\x8f\xb2']
# 伊拉克
# [b'\xe4\xbc\x8a\xe6\x8b\x89\xe5\x85\x8b']
# 692亩
# [b'692\xe4\xba\xa9']
# 750
# [b'750']
# 518
# [b'518']
# 特斯拉
# [b'\xe7\x89\xb9\xe6\x96\xaf\xe6\x8b\x89']
# 四方区
# [b'\xe5\x9b\x9b\xe6\x96\xb9\xe5\x8c\xba']
# 铝合金
# [b'\xe9\x93\x9d\xe5\x90\x88\xe9\x87\x91']
# 晴明草薙剑
# [b'\xe6\x99\xb4\xe6\x98\x8e\xe8\x8d\x89\xe8\x96\x99\xe5\x89\x91']
# 诸葛亮
# [b'\xe8\xaf\xb8\xe8\x91\x9b\xe4\xba\xae']
# 两种
# [b'\xe4\xb8\xa4\xe7\xa7\x8d']
# 黑龙江省
# [b'\xe9\xbb\x91\xe9\xbe\x99\xe6\xb1\x9f\xe7\x9c\x81']
# 衡水市
# [b'\xe8\xa1\xa1\xe6\xb0\xb4\xe5\xb8\x82']
# 月经
# [b'\xe6\x9c\x88\xe7\xbb\x8f']
# 铁达
# [b'\xe9\x93\x81\xe8\xbe\xbe']
# 14年
# [b'14\xe5\xb9\xb4']
# 4个
# [b'4\xe4\xb8\xaa']
# 德国
# [b'\xe5\xbe\xb7\xe5\x9b\xbd']
# 6年
# [b'6\xe5\xb9\xb4']
# 陈百祥
# [b'\xe9\x99\x88\xe7\x99\xbe\xe7\xa5\xa5']
# 海尔
# [b'\xe6\xb5\xb7\xe5\xb0\x94']
# 1927年
# [b'1927\xe5\xb9\xb4']
# 南沙群岛
# [b'\xe5\x8d\x97\xe6\xb2\x99\xe7\xbe\xa4\xe5\xb2\x9b']
# 李白
# [b'\xe6\x9d\x8e\xe7\x99\xbd']
# 涪陵区
# [b'\xe6\xb6\xaa\xe9\x99\xb5\xe5\x8c\xba']
# 日本丰田公司
# [b'\xe6\x97\xa5\xe6\x9c\xac\xe4\xb8\xb0\xe7\x94\xb0\xe5\x85\xac\xe5\x8f\xb8']
# 6号
# [b'6\xe5\x8f\xb7']
# 浅绿色
# [b'\xe6\xb5\x85\xe7\xbb\xbf\xe8\x89\xb2']
# 二氧化碳
# [b'\xe4\xba\x8c\xe6\xb0\xa7\xe5\x8c\x96\xe7\xa2\xb3']
# 山顶洞人
# [b'\xe5\xb1\xb1\xe9\xa1\xb6\xe6\xb4\x9e\xe4\xba\xba']
# 英寸
# [b'\xe8\x8b\xb1\xe5\xaf\xb8']
# 林志颖
# [b'\xe6\x9e\x97\xe5\xbf\x97\xe9\xa2\x96']
# 欢乐颂
# [b'\xe6\xac\xa2\xe4\xb9\x90\xe9\xa2\x82']
# 45
# [b'45']
# 独角仙
# [b'\xe7\x8b\xac\xe8\xa7\x92\xe4\xbb\x99']
# 沙特阿拉伯
# [b'\xe6\xb2\x99\xe7\x89\xb9\xe9\x98\xbf\xe6\x8b\x89\xe4\xbc\xaf']
# 张江
# [b'\xe5\xbc\xa0\xe6\xb1\x9f']
# 三线
# [b'\xe4\xb8\x89\xe7\xba\xbf']
# 回族
# [b'\xe5\x9b\x9e\xe6\x97\x8f']
# 汇金公司
# [b'\xe6\xb1\x87\xe9\x87\x91\xe5\x85\xac\xe5\x8f\xb8']
# 苏丹
# [b'\xe8\x8b\x8f\xe4\xb8\xb9']
# 分米
# [b'\xe5\x88\x86\xe7\xb1\xb3']
# 76集
# [b'76\xe9\x9b\x86']
# 黄陂区
# [b'\xe9\xbb\x84\xe9\x99\x82\xe5\x8c\xba']
# 11.4厘米
# [b'11', b'4\xe5\x8e\x98\xe7\xb1\xb3']
# 鸟
# [b'\xe9\xb8\x9f']
# 染色体
# [b'\xe6\x9f\x93\xe8\x89\xb2\xe4\xbd\x93']
# 孙武
# [b'\xe5\xad\x99\xe6\xad\xa6']
# 铝合金
# [b'\xe9\x93\x9d\xe5\x90\x88\xe9\x87\x91']
# 谏言
# [b'\xe8\xb0\x8f\xe8\xa8\x80']
# 卡罗尔
# [b'\xe5\x8d\xa1\xe7\xbd\x97\xe5\xb0\x94']
# 小鼓
# [b'\xe5\xb0\x8f\xe9\xbc\x93']
# 2
# [b'2']
# 14
# [b'14']
# 澳大利亚
# [b'\xe6\xbe\xb3\xe5\xa4\xa7\xe5\x88\xa9\xe4\xba\x9a']
# 郑州市
# [b'\xe9\x83\x91\xe5\xb7\x9e\xe5\xb8\x82']
# 2寸
# [b'2\xe5\xaf\xb8']
# 张店区
# [b'\xe5\xbc\xa0\xe5\xba\x97\xe5\x8c\xba']
# 二线
# [b'\xe4\xba\x8c\xe7\xba\xbf']
# 杨利伟
# [b'\xe6\x9d\xa8\xe5\x88\xa9\xe4\xbc\x9f']
# 1974年
# [b'1974\xe5\xb9\xb4']
# 程诗迦
# [b'\xe7\xa8\x8b\xe8\xaf\x97\xe8\xbf\xa6']
# 鲍姆
# [b'\xe9\xb2\x8d\xe5\xa7\x86']
# 毛细
# [b'\xe6\xaf\x9b\xe7\xbb\x86']
# 日本
# [b'\xe6\x97\xa5\xe6\x9c\xac']
# 诸葛亮
# [b'\xe8\xaf\xb8\xe8\x91\x9b\xe4\xba\xae']
# 北美洲
# [b'\xe5\x8c\x97\xe7\xbe\x8e\xe6\xb4\xb2']
# 杨千桦
# [b'\xe6\x9d\xa8\xe5\x8d\x83\xe6\xa1\xa6']
# 37周
# [b'37\xe5\x91\xa8']
# 东莞
# [b'\xe4\xb8\x9c\xe8\x8e\x9e']
# query-level precision=9938/9938=1.000000
# character-level average f value=7073.000000/9938.000000=0.711713
# 1.0 0.7117126182330449 0.8558563091165224
# 准确率 9 1.0 0.7117126182330449 0.8558563091165224
# learning rate: 0.001
# acc: 1.0000, f1: 0.7117, final: 0.8559, best final: 0.8559

# %%
with open('tmp_result.txt', "r") as infile, open('out_result.txt', "w") as outfile:
    infile = infile.readlines()
    print(len(infile))
# Out:
# 9938
